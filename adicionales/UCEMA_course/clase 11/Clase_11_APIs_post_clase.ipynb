# %% [markdown]
# # Mas funciones de la API AlphaVantage

# %%
import requests
import pandas as pd

# %%
apikey = '2RG2NEF3IPXMIPX3'
apikey = '09QXTWMZ1UBWMPO8'
apikey = '09QXTWMZ1UBWMPO8'

# %% [markdown]
# ## Series diarias

# %%
def getDaily(symbol, size, auto_adjust=False):

    # Request http
    function='TIME_SERIES_DAILY'
    url = 'https://www.alphavantage.co/query'
    parametros = {'function' : function, 'symbol': symbol, 
                  'outputsize': size, 'apikey': apikey}

    r = requests.get(url, params=parametros)
    
    
    # trabajar con lo que me devuelve
    # Manejo de errores
    data = r.json()['Time Series (Daily)']
    df = pd.DataFrame.from_dict(data, orient='index')
    df = df.astype('float')
    df.index.name = 'Date'
    df.columns = ['Open','High','Low','Close','Volume']
    df = df.sort_values('Date', ascending=True)
    df.index = pd.to_datetime(df.index)  
    
    
    # de tarea agregar lo necesario aca adentro para que tenga la misma funcionalidad que yfinance
    # trabajando con el parametro auto_adjust
    
    return df

# %%
data = getDaily(symbol='AAPL', size='full')
data
# Out:
#               Open    High     Low   Close      Volume
# Date
# 1999-11-01   80.00   80.69   77.37   77.62   2487300.0
# 1999-11-02   78.00   81.69   77.31   80.25   3564600.0
# 1999-11-03   81.62   83.25   81.00   81.50   2932700.0
# 1999-11-04   82.06   85.37   80.62   83.62   3384700.0
# 1999-11-05   84.62   88.37   84.00   88.31   3721500.0
# ...            ...     ...     ...     ...         ...
# 2021-06-09  127.21  127.75  126.52  127.13  56877937.0
# 2021-06-10  127.02  128.19  125.94  126.11  71186421.0
# 2021-06-11  126.53  127.44  126.10  127.35  53522373.0
# 2021-06-14  127.82  130.54  127.07  130.48  96906490.0
# 2021-06-15  129.94  130.59  129.39  129.64  62657656.0
#
# [5440 rows x 5 columns]

# %% [markdown]
# ## Series Ajustadas

# %%
def getDailyAdj(symbol, size):
    function='TIME_SERIES_DAILY_ADJUSTED'
    url = 'https://www.alphavantage.co/query'
    parametros = {'function' : function, 'symbol': symbol, 
                  'outputsize': size, 'apikey': apikey}

    r = requests.get(url, params=parametros)
    data = r.json()['Time Series (Daily)']
    df = pd.DataFrame.from_dict(data, orient='index')
    df = df.astype('float')
    df.index.name = 'Date'
    df.columns = ['Open','High','Low','Close','AdjustedClose','Volume','DividendAmount','SplitCoefficient']
    # Hacer esta linea anterior automatizada
    
    df = df.sort_values('Date', ascending=True).round(2)
    df.index = pd.to_datetime(df.index)    
    return df

data = getDailyAdj(symbol='AAPL', size='compact')
data
# Out:
#               Open    High     Low   Close  AdjustedClose       Volume  \
# Date
# 2021-01-22  136.28  139.85  135.02  139.07         138.63  114459360.0
# 2021-01-25  143.07  145.09  136.54  142.92         142.47  157611713.0
# 2021-01-26  143.60  144.30  141.37  143.16         142.70   98390555.0
# 2021-01-27  143.43  144.30  140.41  142.06         141.61  140843759.0
# 2021-01-28  139.52  141.99  136.70  137.09         136.65  142621128.0
# ...            ...     ...     ...     ...            ...          ...
# 2021-06-09  127.21  127.75  126.52  127.13         127.13   56877937.0
# 2021-06-10  127.02  128.19  125.94  126.11         126.11   71186421.0
# 2021-06-11  126.53  127.44  126.10  127.35         127.35   53522373.0
# 2021-06-14  127.82  130.54  127.07  130.48         130.48   96906490.0
# 2021-06-15  129.94  130.59  129.39  129.64         129.64   62660636.0
#
#             DividendAmount  SplitCoefficient
# Date
# 2021-01-22             0.0               1.0
# 2021-01-25             0.0               1.0
# 2021-01-26             0.0               1.0
# 2021-01-27             0.0               1.0
# 2021-01-28             0.0               1.0
# ...                    ...               ...
# 2021-06-09             0.0               1.0
# 2021-06-10             0.0               1.0
# 2021-06-11             0.0               1.0
# 2021-06-14             0.0               1.0
# 2021-06-15             0.0               1.0
#
# [100 rows x 8 columns]

# %% [markdown]
# Por ejemplo si con este request quiero ver todas las ruedas donde se aplicó split a AAPL, solo pongo:

# %%
data = getDailyAdj(symbol='AAPL', size='full')
data.loc[data.SplitCoefficient > 1]
# Out:
#               Open    High     Low   Close  AdjustedClose       Volume  \
# Date
# 2000-06-21   50.50   56.94   50.31   55.63           0.85    4375000.0
# 2005-02-28   44.68   45.14   43.96   44.86           1.38   11635900.0
# 2014-06-09   92.70   93.88   91.75   93.70          21.07   75414997.0
# 2020-08-31  127.58  131.00  126.00  129.04         128.41  223505733.0
#
#             DividendAmount  SplitCoefficient
# Date
# 2000-06-21             0.0               2.0
# 2005-02-28             0.0               2.0
# 2014-06-09             0.0               7.0
# 2020-08-31             0.0               4.0

# %% [markdown]
# O si quiero saber la cantidad de ruedas donde KO pagó dividendos en los ultimos 20 años (la API me trae valores de los ultimos 20 años)

# %%
data = getDailyAdj(symbol='KO', size='full')
data.loc[data.DividendAmount > 0]
# Out:
#              Open   High    Low  Close  AdjustedClose      Volume  \
# Date
# 1999-11-29  65.88  67.19  65.75  67.06          18.68   4260100.0
# 2000-03-13  43.25  44.31  43.13  43.75          12.24   7823200.0
# 2000-06-13  53.00  54.00  52.81  53.38          14.98   2813100.0
# 2000-09-13  53.50  53.69  52.06  52.50          14.78   3493200.0
# 2000-11-29  59.75  62.50  59.75  62.13          17.54   4846000.0
# ...           ...    ...    ...    ...            ...         ...
# 2020-06-12  46.21  46.25  45.01  45.60          44.17  21813209.0
# 2020-09-14  50.97  51.23  50.57  50.71          49.52  10911657.0
# 2020-11-30  52.09  52.19  51.08  51.60          50.79  43203587.0
# 2021-03-12  50.59  50.68  50.20  50.36          49.98  17598594.0
# 2021-06-14  55.69  55.71  55.20  55.55          55.55   9493794.0
#
#             DividendAmount  SplitCoefficient
# Date
# 1999-11-29            0.16               1.0
# 2000-03-13            0.17               1.0
# 2000-06-13            0.17               1.0
# 2000-09-13            0.17               1.0
# 2000-11-29            0.17               1.0
# ...                    ...               ...
# 2020-06-12            0.41               1.0
# 2020-09-14            0.41               1.0
# 2020-11-30            0.41               1.0
# 2021-03-12            0.42               1.0
# 2021-06-14            0.42               1.0
#
# [87 rows x 8 columns]

# %% [markdown]
# Bueno, si seguimos explorando la Doc de la API vemos que tiene las siguientes funciones:

# %% [markdown]
# * TIME_SERIES_WEEKLY
# * TIME_SERIES_WEEKLY_ADJUSTED
# * TIME_SERIES_MONTHLY
# * TIME_SERIES_MONTHLY_ADJUSTED

# %%
def getHist(symbol, ......,adjusted='False', interval='1d'):
    
    if interval == '1d'
        if adjusted == True:
            ret = getDailyAdj(....)
        else:
            ret = getDaily(...)
    elif interval == 'weekly':
        ret = getWeekly(...)

# %% [markdown]
# ### Cotización actual

# %% [markdown]
# La llamada para esta función es function='GLOBAL_QUOTE' y el parámetro obligatorio aparte del token es el "symbol"

# %%
def quote(symbol):
    function='GLOBAL_QUOTE'
    url = 'https://www.alphavantage.co/query'
    parametros = {'function':function, 'symbol':symbol, 'apikey':apikey}

    r = requests.get(url, params=parametros)
    return r.json()

data = quote(symbol='AAPL')
data
# Out:
# {'Global Quote': {'01. symbol': 'AAPL',
#   '02. open': '126.5300',
#   '03. high': '127.4400',
#   '04. low': '126.1000',
#   '05. price': '127.3500',
#   '06. volume': '53522373',
#   '07. latest trading day': '2021-06-11',
#   '08. previous close': '126.1100',
#   '09. change': '1.2400',
#   '10. change percent': '0.9833%'}}

# %% [markdown]
# ### Cotizaciones de otros mercados

# %%
data = quote(symbol='PETR3.SAO')
data
# Out:
# {'Global Quote': {'01. symbol': 'PETR3.SAO',
#   '02. open': '29.5800',
#   '03. high': '29.7000',
#   '04. low': '29.0700',
#   '05. price': '29.3000',
#   '06. volume': '15316600',
#   '07. latest trading day': '2021-06-11',
#   '08. previous close': '29.5300',
#   '09. change': '-0.2300',
#   '10. change percent': '-0.7789%'}}

# %% [markdown]
# ### Búsqueda de Activos

# %%
def search(keywords):
    function='SYMBOL_SEARCH'
    url = 'https://www.alphavantage.co/query'
    parametros = {'function':function, 'keywords':keywords, 'apikey':apikey}

    r = requests.get(url, params=parametros)
    js= r.json()['bestMatches']
    df = pd.DataFrame(js)
    return df

data = search(keywords='petro')
data
# Out:
#     1. symbol                       2. name 3. type         4. region  \
# 0       PETRY  Petrobras Distribuidora S.A.  Equity     United States
# 1         PTR            PetroChina Co. Ltd  Equity     United States
# 2         PZE        Petrobras Argentina SA  Equity     United States
# 3       PEFGF          Petrobras Energ  Ord  Equity     United States
# 4       PTIFF          Petroceltic Intl Ord  Equity     United States
# 5  601857.SHH        PetroChina Company Ltd  Equity          Shanghai
# 6    PC6A.FRK    PetroChina Company Limited  Equity         Frankfurt
# 7     PC6.FRK    PetroChina Company Limited  Equity         Frankfurt
# 8   BRDT3.SAO   Petrobras Distribuidora S.A  Equity  Brazil/Sao Paolo
# 9       PCCYF  PetroChina Co. Ltd - Class H  Equity     United States
#
#   5. marketOpen 6. marketClose 7. timezone 8. currency 9. matchScore
# 0         09:30          16:00      UTC-04         USD        0.8000
# 1         09:30          16:00      UTC-04         USD        0.7500
# 2         09:30          16:00      UTC-04         USD        0.5000
# 3         09:30          16:00      UTC-04         USD        0.4000
# 4         09:30          16:00      UTC-04         USD        0.4000
# 5         09:30          15:00      UTC+08         CNY        0.3704
# 6         08:00          20:00      UTC+02         EUR        0.3226
# 7         08:00          20:00      UTC+02         EUR        0.3226
# 8         10:00          17:30      UTC-03         BRL        0.3125
# 9         09:30          16:00      UTC-04         USD        0.3030

# %% [markdown]
# ### FOREX

# %%
def fx(fromC, toC):
    function='CURRENCY_EXCHANGE_RATE'
    url = 'https://www.alphavantage.co/query'
    parametros = {'function':function, 'from_currency':fromC, 
                  'to_currency':toC, 'apikey':apikey}

    r = requests.get(url, params=parametros)
    return r.json()

data = fx('USD','ARS')
print(json.dumps(data, indent=3))
# Out:
# {
#    "Realtime Currency Exchange Rate": {
#       "1. From_Currency Code": "USD",
#       "2. From_Currency Name": "United States Dollar",
#       "3. To_Currency Code": "ARS",
#       "4. To_Currency Name": "Argentine Peso",
#       "5. Exchange Rate": "95.13000000",
#       "6. Last Refreshed": "2021-06-14 08:16:31",
#       "7. Time Zone": "UTC",
#       "8. Bid Price": "95.12800000",
#       "9. Ask Price": "95.13200000"
#    }
# }

# %% [markdown]
# También la API me permite obtener el intradiario del par con la función FX_INTRADAY

# %%
def fxIntra(fromC, toC, interval):
    function='FX_INTRADAY'
    url = 'https://www.alphavantage.co/query'
    parametros = {'function':function, 'from_symbol':fromC, 
                  'to_symbol':toC, 'interval':interval,'apikey':apikey}

    r = requests.get(url, params=parametros)
    js = r.json()['Time Series FX ('+ interval +')']
    
    df = pd.DataFrame.from_dict(js, orient='index')
    df = df.astype('float')
    df.index.name = 'Date'
    df.columns = ['Open','High','Low','Close']
    df = df.sort_values('Date', ascending=True).round(2)
    df.index = pd.to_datetime(df.index)    
    return df

data = fxIntra('USD','ARS','5min')
data
# Out:
#                       Open   High    Low  Close
# Date
# 2021-06-15 13:45:00  95.28  95.28  95.28  95.28
# 2021-06-15 13:50:00  95.28  95.28  95.28  95.28
# 2021-06-15 13:55:00  95.28  95.28  95.28  95.28
# 2021-06-15 14:00:00  95.28  95.28  95.28  95.28
# 2021-06-15 14:05:00  95.28  95.28  95.28  95.28
# ...                    ...    ...    ...    ...
# 2021-06-15 21:40:00  95.09  95.09  95.09  95.09
# 2021-06-15 21:45:00  95.09  95.09  95.09  95.09
# 2021-06-15 21:50:00  95.09  95.09  95.09  95.09
# 2021-06-15 21:55:00  95.09  95.09  95.09  95.09
# 2021-06-15 22:00:00  95.09  95.09  95.09  95.09
#
# [100 rows x 4 columns]

# %% [markdown]
# De modo muy similar a las funciones de equity historicos tenemos para Forex

# %%
def fxDaily(fromC, toC, size):
    function='FX_DAILY'
    url = 'https://www.alphavantage.co/query'
    parametros = {'function':function, 'from_symbol':fromC, 'to_symbol':toC, 
                  'outputsize':size ,'apikey':apikey}

    r = requests.get(url, params=parametros)
    js = r.json()['Time Series FX (Daily)']
    df = pd.DataFrame.from_dict(js, orient='index')
    df = df.astype('float')
    df.index.name = 'Date'
    df.columns = ['Open','High','Low','Close']
    df = df.sort_values('Date', ascending=True).round(2)
    df.index = pd.to_datetime(df.index)    
    return df

data = fxDaily('USD','ARS','full')
data
# Out:
#              Open   High    Low  Close
# Date
# 2014-11-24   8.51   8.52   8.51   8.52
# 2014-11-25   8.52   8.52   8.51   8.52
# 2014-11-26   8.52   8.52   8.52   8.52
# 2014-11-27   8.52   8.52   8.52   8.52
# 2014-11-28   8.52   8.53   8.52   8.53
# ...           ...    ...    ...    ...
# 2021-06-08  94.78  95.01  94.78  94.82
# 2021-06-09  94.82  95.06  94.82  95.05
# 2021-06-10  95.05  95.09  95.05  95.09
# 2021-06-11  95.09  95.13  94.90  95.13
# 2021-06-14  95.13  95.13  95.13  95.13
#
# [1711 rows x 4 columns]

# %% [markdown]
# Y no se los muestra pero es exactamente igual para monthly y weekly con las funciones:
# * FX_WEEKLY
# * FX_MONTHLY

# %% [markdown]
# ### Crypto

# %%
def cryptoRank(symbol):
    function='CRYPTO_RATING'
    url = 'https://www.alphavantage.co/query'
    parametros = {'function':function, 'symbol':symbol, 'apikey':apikey}

    r = requests.get(url, params=parametros)
    return r.json()

data = cryptoRank('BTC')
print(json.dumps(data, indent=3))
# Out:
# {
#    "Crypto Rating (FCAS)": {
#       "1. symbol": "BTC",
#       "2. name": "Bitcoin",
#       "3. fcas rating": "Attractive",
#       "4. fcas score": "895",
#       "5. developer score": "848",
#       "6. market maturity score": "880",
#       "7. utility score": "957",
#       "8. last refreshed": "2021-06-15 00:00:00",
#       "9. timezone": "UTC"
#    }
# }

# %%
data = cryptoRank('ADA')
print(json.dumps(data, indent=3))
# Out:
# {
#    "Crypto Rating (FCAS)": {
#       "1. symbol": "ADA",
#       "2. name": "Cardano",
#       "3. fcas rating": "Superb",
#       "4. fcas score": "965",
#       "5. developer score": "966",
#       "6. market maturity score": "904",
#       "7. utility score": "976",
#       "8. last refreshed": "2021-06-13 00:00:00",
#       "9. timezone": "UTC"
#    }
# }

# %% [markdown]
# ## Indicadores Técnicos

# %% [markdown]
# Medias Móviles:
#
# *  SMA, EMA, WMA (Medias móviles simple, exponencial y ponderada)
# *  DEMA, TEMA (Media movil doble exponencial y triple)
# *  TRIMA (Media exponencial triangular)
# *  KAMA (Media movil adaptativa: Kaufman)
# *  MAMA (MESA adaptive moving average, otra media movil adaptativa)
#
# Inidicadores Super conocidos:
# *  MACD (El conocidísimo oscilador ideal para ver divergengias)
# *  STOCH, STOCHF (El conocido osiclador estacástico)
# *  RSI (El conocidísimo oscilador de Fuerza relativa ideal para divergencias)
# *  ADX (Indicador de tendencia, conocidisimo como Average Directional Movement Index)
# *  DX (Es el ADX pero sin suavizar)
#
#
# *  CCI (Commodity channel index, Indicador de inicio y fin de tendencias, zonas de sobrecompra/sobreventa o divergencias)
# *  AROON (Anticipador de inicios de tendencias compuesto por dos curvas)
# *  BBANDS (Famosas bandas de bollinger, bandas de rango de movimiento a +/- 2 sigmas de media movil)
# *  SAR (famoso Parabolic SAR, se usa como Trailing StopLoss para cerrar posiciones)
#
#
# *  ATR (Average true range,es la media movil del True Range, es decir la media movil del rango de movimiento, proxy de la volatilidad pero en terminos absolutos)
#
#
# *  VWAP (Precio ponderado por volumen)
# *  OBV (On Balance Volume, acumulador del volumen, cuando cierra Up se suma vol, y cuendo cierra abajo se resta)
# *  AD (Chaikin Acumulación/Distribución, una mejora del OBV con una ponderación de la forma de la vela)
#
# Otros inidicadores
# *  T3 (Una media movil basada en la doble exponencial)
# *  MACDEXT (Es el MACD con la posibilidad de usar otros tipos de medias móviles que la EMA)
# *  STOCHRSI (Oscilador estocastico del oscilador RSI)
# *  WILLR (Oscilador de Williams, similar al estocástico)
# *  ADXR (Promedio del ADX contra el ADX de "n" ruedas atras)
# *  APO (Absolute price oscillator, Es una diferencia de medias móviles, simples, exponenciales, etc)
# *  PPO (Percentage price oscillator, Es la diferencia porcentual de las medias moviles)
# *  MOM (El famoso "Momentum", es la diferencia entre el precio y el precio "n" ruedas atrás)
# *  BOP (Balance of power) dado el OHLC es la media movil de (C-O)/(H-L), se supone que cuando pasa de negativo a positivo marca señal de compra y viceversa
# *  CMO (Chande momentum oscillator, es una variante del oscilador RSI)
# *  ROC (Es como el Momentum pero %, mide variación % respecto a "n" ruedas atrás)
# *  AROONOSC (Es la diferencia entre las curvas del AROON)
# *  MFI (Money flow index, es un oscilador que se interpreta como el RSI y que tiene en cuenta el volumen)
# *  TRIX (Es un oscilador de la TEMA respecto de "n" ruedas atrás)
# *  ULTOSC (Ultimate oscillator, es un osclador de 3 períodos, como promediar 3 RSIs con 3 "n" diferentes)
# *  MINUS_DI, PLUS_DI, MINUS_DM, PLUS_DM (Componentes del ADX)
# *  MIDPOINT (El promedio entre el Maximo y Mínimo de una serie de "n" velas puede ser de el "H" el "O", "L" o "C")
# *  MIDPRICE (El promedio entre el Máximo "High" y Mínimo "Low" de la serie de "n" velas)
# *  TRANGE (True range, es un estimador del rango normal de trading o movimiento)
# *  ADOSC (Oscilador del Chaikin AD)
# *  HT_TRENDLINE, HT_SINE, HT_TRENDMODE, HT_DCPERIOD, HT_DCPHASE, HT_PHASOR, son todos indicadores de la "descomposición" de los precios en la transformada de Hilbert, es un método usado para el procesamiento de señales

# %% [markdown]
# Link con formulas:
#
# * https://www.fmlabs.com/reference/default.htm
# * https://docs.anychart.com/Stock_Charts/Technical_Indicators/Mathematical_Description#overview

# %% [markdown]
# ### Medias Móviles

# %% [markdown]
# Puedo hacer una función para cada tipo de media movil, de la siguiente forma por ejemplo para la SMA:

# %%
def SMA(symbol, interval, series_type, time_period):
    function='SMA'
    url = 'https://www.alphavantage.co/query'
    parametros = {'function':function, 'symbol':symbol, 'interval':interval, 
                  'series_type':series_type,'time_period':time_period ,'apikey':apikey}

    r = requests.get(url, params=parametros)
    js = r.json()['Technical Analysis: SMA']
    df = pd.DataFrame.from_dict(js, orient='index')
    df = df.astype('float')
    df.index.name = 'Date'
    df = df.sort_values('Date', ascending=True).round(2)
    df.index = pd.to_datetime(df.index)    
    return df

data = SMA('AAPL','5min','close', 50)
data
# Out:
#                         SMA
# Date
# 2021-05-17 08:25:00  126.90
# 2021-05-17 08:30:00  126.89
# 2021-05-17 08:35:00  126.89
# 2021-05-17 08:40:00  126.89
# 2021-05-17 08:45:00  126.90
# ...                     ...
# 2021-06-11 19:40:00  127.26
# 2021-06-11 19:45:00  127.27
# 2021-06-11 19:50:00  127.27
# 2021-06-11 19:55:00  127.28
# 2021-06-11 20:00:00  127.28
#
# [3464 rows x 1 columns]

# %% [markdown]
# De esa forma obtuve la media movil de 50 velas de los precios de cierre, en un timeframe de 5min de AAPL
# <br><br>Ahora bien, si quisiera calcular en lugar de la SMA la EMA, si veo la doc de la API son exactamente los mismo parámetros que la SMA, solo cambia el parámetro "function" que en lugar de ser "SMA" es "EMA" por lo tanto andar haciendo funciones diferentes para cada tipo de media movil, lo mejor es definir una sola función que tome el tipo de media movil como parámetro y listo, sería algo  así:

# %%
def movingAv(symbol, interval, series_type, time_period, mean_type='SMA'):
    function = mean_type
    url = 'https://www.alphavantage.co/query'
    parametros = {'function':function, 'symbol':symbol, 'interval':interval, 
                  'series_type':series_type,'time_period':time_period ,'apikey':apikey}

    r = requests.get(url, params=parametros)
    js = r.json()['Technical Analysis: '+mean_type]
    df = pd.DataFrame.from_dict(js, orient='index')
    df = df.astype('float')
    df.index.name = 'Date'
    df = df.sort_values('Date', ascending=True).round(2)
    df.index = pd.to_datetime(df.index)    
    return df

data = movingAv('AAPL','5min','close', 50, 'TRIMA')
data
# Out:
#                       TRIMA
# Date
# 2021-05-17 08:25:00  126.90
# 2021-05-17 08:30:00  126.89
# 2021-05-17 08:35:00  126.89
# 2021-05-17 08:40:00  126.88
# 2021-05-17 08:45:00  126.87
# ...                     ...
# 2021-06-11 19:40:00  127.27
# 2021-06-11 19:45:00  127.27
# 2021-06-11 19:50:00  127.27
# 2021-06-11 19:55:00  127.27
# 2021-06-11 20:00:00  127.27
#
# [3464 rows x 1 columns]

# %% [markdown]
# Ahora con esta función si quiero la Triple Exponencial solo cambio ese argumento cuando llamo a la función y ya

# %%
data = movingAv('AAPL','daily','close', 50, 'TEMA')
data
# Out:
#               TEMA
# Date
# 2000-06-01    0.69
# 2000-06-02    0.69
# 2000-06-05    0.68
# 2000-06-06    0.68
# 2000-06-07    0.68
# ...            ...
# 2021-06-07  125.42
# 2021-06-08  125.46
# 2021-06-09  125.55
# 2021-06-10  125.51
# 2021-06-11  125.62
#
# [5291 rows x 1 columns]

# %% [markdown]
# ### MACD

# %%
def MACD(symbol, interval, series_type='close', fastperiod=12, slowperiod=26, signalperiod=9):
    function='MACD'
    url = 'https://www.alphavantage.co/query'
    parametros = {'function':function, 'symbol':symbol, 'interval':interval, 
                  'series_type':series_type, 'fastperiod': fastperiod, 
                  'slowperiod':slowperiod, 'signalperiod':signalperiod,
                  'apikey':apikey }

    r = requests.get(url, params=parametros)
    js = r.json()['Technical Analysis: MACD']
    df = pd.DataFrame.from_dict(js, orient='index')
    df = df.astype('float')
    df.index.name = 'Date'
    df = df.sort_values('Date', ascending=True).round(2)
    df.index = pd.to_datetime(df.index)    
    return df

data = MACD('AAPL','5min')
data
# Out:
#                      MACD_Signal  MACD_Hist  MACD
# Date
# 2021-05-17 07:05:00        -0.05      -0.02 -0.07
# 2021-05-17 07:10:00        -0.05      -0.02 -0.07
# 2021-05-17 07:15:00        -0.06      -0.01 -0.07
# 2021-05-17 07:20:00        -0.06      -0.00 -0.06
# 2021-05-17 07:25:00        -0.06       0.00 -0.06
# ...                          ...        ...   ...
# 2021-06-11 19:40:00         0.00       0.00  0.01
# 2021-06-11 19:45:00         0.01       0.00  0.01
# 2021-06-11 19:50:00         0.01       0.01  0.01
# 2021-06-11 19:55:00         0.01       0.01  0.02
# 2021-06-11 20:00:00         0.01       0.01  0.02
#
# [3480 rows x 3 columns]

# %% [markdown]
# # API de Ameritrade

# %% [markdown]
# Para acceder a la API de TDA el broker ameritrade, hay que ingresar a https://developer.tdameritrade.com/
#
# Y obviamente sacarse una cuenta de usuario gratuita, yo saqué la mia

# %% [markdown]
# Una vez creada la cuenta tienen que crear una app para que le den una "Consumer Key" similar a esta:

# %%
c_key = 'AHSA7C8FWZZFRG1W15WOJLQY8WRSCOVI'
c_key = "NYF6LZZITQAOCYNQHYUZOJF4XGDPT0KK"

# %% [markdown]
# Una vez obtenida la key pueden usarla para llamar a la API

# %%
import requests

# %%
def getQuote(symbol, c_key):
    endpoint = 'https://api.tdameritrade.com/v1/marketdata/'+symbol+'/quotes?'
    
    p  ={'apikey' : c_key}
    r = requests.get(url=endpoint ,params=p)
    return r.json()[symbol]

quote = getQuote('AAPL', c_key)
quote
# Out:
# {'assetType': 'EQUITY',
#  'assetMainType': 'EQUITY',
#  'cusip': '037833100',
#  'symbol': 'AAPL',
#  'description': 'Apple Inc. - Common Stock',
#  'bidPrice': 129.66,
#  'bidSize': 100,
#  'bidId': 'P',
#  'askPrice': 129.69,
#  'askSize': 200,
#  'askId': 'P',
#  'lastPrice': 129.66,
#  'lastSize': 0,
#  'lastId': 'P',
#  'openPrice': 129.94,
#  'highPrice': 130.6,
#  'lowPrice': 129.39,
#  'bidTick': ' ',
#  'closePrice': 130.48,
#  'netChange': -0.82,
#  'totalVolume': 62696800,
#  'quoteTimeInLong': 1623797351768,
#  'tradeTimeInLong': 1623797351768,
#  'mark': 129.66,
#  'exchange': 'q',
#  'exchangeName': 'NASD',
#  'marginable': True,
#  'shortable': True,
#  'volatility': 0.0062,
#  'digits': 4,
#  '52WkHigh': 145.09,
#  '52WkLow': 83.145,
#  'nAV': 0.0,
#  'peRatio': 28.5766,
#  'divAmount': 0.88,
#  'divYield': 0.67,
#  'divDate': '2021-05-07 00:00:00.000',
#  'securityStatus': 'Normal',
#  'regularMarketLastPrice': 129.64,
#  'regularMarketLastSize': 52687,
#  'regularMarketNetChange': -0.84,
#  'regularMarketTradeTimeInLong': 1623787200959,
#  'netPercentChangeInDouble': -0.6284,
#  'markChangeInDouble': -0.82,
#  'markPercentChangeInDouble': -0.6284,
#  'regularMarketPercentChangeInDouble': -0.6438,
#  'delayed': True,
#  'realtimeEntitled': False}

# %%
def getQuotes(symbols):
    
    endpoint = 'https://api.tdameritrade.com/v1/marketdata/quotes'
    r = requests.get(url=endpoint, params={'apikey' : c_key, 'symbol':symbols})
    
    return r.json()

quotes = getQuotes('AAPL,YPF')

quotes.keys()
# Out:
# dict_keys(['AAPL', 'YPF'])

# %%
quotes['YPF']
# Out:
# {'assetType': 'EQUITY',
#  'assetMainType': 'EQUITY',
#  'cusip': '984245100',
#  'assetSubType': 'ADR',
#  'symbol': 'YPF',
#  'description': 'YPF Sociedad Anonima Common Stock',
#  'bidPrice': 5.22,
#  'bidSize': 300,
#  'bidId': 'P',
#  'askPrice': 5.93,
#  'askSize': 2000,
#  'askId': 'K',
#  'lastPrice': 5.43,
#  'lastSize': 39000,
#  'lastId': 'N',
#  'openPrice': 5.44,
#  'highPrice': 5.52,
#  'lowPrice': 5.3,
#  'bidTick': ' ',
#  'closePrice': 5.46,
#  'netChange': -0.03,
#  'totalVolume': 956475,
#  'quoteTimeInLong': 1623788990250,
#  'tradeTimeInLong': 1623796200006,
#  'mark': 5.43,
#  'exchange': 'n',
#  'exchangeName': 'NYSE',
#  'marginable': True,
#  'shortable': True,
#  'volatility': 0.0785,
#  'digits': 2,
#  '52WkHigh': 7.3,
#  '52WkLow': 2.98,
#  'nAV': 0.0,
#  'peRatio': 0.0,
#  'divAmount': 0.0,
#  'divYield': 0.0,
#  'divDate': '',
#  'securityStatus': 'Normal',
#  'regularMarketLastPrice': 5.43,
#  'regularMarketLastSize': 390,
#  'regularMarketNetChange': -0.03,
#  'regularMarketTradeTimeInLong': 1623796200006,
#  'netPercentChangeInDouble': -0.5495,
#  'markChangeInDouble': -0.03,
#  'markPercentChangeInDouble': -0.5495,
#  'regularMarketPercentChangeInDouble': -0.5495,
#  'delayed': True,
#  'realtimeEntitled': False}

# %% [markdown]
# ### Precios históricos

# %% [markdown]
# * Periodos válidos para cada periodType (los del * son los default)
#     * day: 1, 2, 3, 4, 5, 10*
#     * month: 1*, 2, 3, 6
#     * year: 1*, 2, 3, 5, 10, 15, 20
#     * ytd: 1*
#
# * FrequencyType válidos para cada periodType (los del * son los default)
#     * day: minute*
#     * month: daily, weekly*
#     * year: daily, weekly, monthly*
#     * ytd: daily, weekly*
#
# * Frequency válidos para cada FrequencyType (los del * son los default)
#     * minute: 1*, 5, 10, 15, 30
#     * daily: 1*
#     * weekly: 1*
#     * monthly: 1*

# %% [markdown]
# Otros parámetros posibles:
#     * startDate: timestamp milisegundos desde epoch
#     * endDate: timestamp milisegundos desde epoch

# %%
import pandas as pd

def getHist(symbol, periodT='day', period=1, freqT='minute', freq=1, na='true'):
    
    
    params = {'symbol':symbol, 'periodType':periodT, 'period':period, 
              'apikey' : c_key, 'frequencyType':freqT, 'frequency':freq ,
              'needExtendedHoursData':na}
    
    url_base='https://api.tdameritrade.com/v1/marketdata/'
    
    endpoint = url_base + symbol+'/pricehistory'
    
    r = requests.get(url=endpoint, params=params)  # data, json
    try:
        js = r.json()['candles']
        df = pd.DataFrame(js)
        df['fecha'] = pd.to_datetime(df.datetime - 3600*1000*3, unit='ms')
    except:
        print('Error, ojo que tenemos una rta inesperada', r.json())
        df = pd.DataFrame()
        
    return df

data = getHist('GGAL', periodT='day', period=1, freqT='minute', freq=1, na='false')
data
# Out:
#        open    high      low   close  volume       datetime  \
# 0     9.920   9.920   9.7900   9.840   50410  1623677400000
# 1     9.950   9.960   9.9500   9.960     299  1623677580000
# 2     9.960   9.960   9.9600   9.960     450  1623677640000
# 3     9.940   9.970   9.9400   9.950    7598  1623677760000
# 4     9.990  10.010   9.9899  10.010    3900  1623677820000
# ..      ...     ...      ...     ...     ...            ...
# 340  10.100  10.100  10.0900  10.095    2451  1623700500000
# 341  10.095  10.095  10.0900  10.090    1000  1623700560000
# 342  10.095  10.100  10.0900  10.095    2290  1623700620000
# 343  10.095  10.095  10.0800  10.080   12494  1623700680000
# 344  10.085  10.120  10.0800  10.100   11310  1623700740000
#
#                   fecha
# 0   2021-06-14 10:30:00
# 1   2021-06-14 10:33:00
# 2   2021-06-14 10:34:00
# 3   2021-06-14 10:36:00
# 4   2021-06-14 10:37:00
# ..                  ...
# 340 2021-06-14 16:55:00
# 341 2021-06-14 16:56:00
# 342 2021-06-14 16:57:00
# 343 2021-06-14 16:58:00
# 344 2021-06-14 16:59:00
#
# [345 rows x 7 columns]

# %% [markdown]
# Como verán en este caso usamos un try/except por si pasamos mal algun parámetro pero que ademas del mensaje de error me devuelva igual el dataFrame vacio
#
# Esto es una buena práctica ppara evitar cortes del flujo del script inesperados

# %% [markdown]
# ### Fundamentals

# %%
def fundamentals(symbol, pr='fundamental'):
    
    params = {'apikey' : c_key, 'symbol':symbol, 'projection': pr}
    
    endpoint = 'https://api.tdameritrade.com/v1/instruments'
    
    r = requests.get(url=endpoint ,params=params)
    return r.json()

fundamentals('AAPL')
# Out:
# {'AAPL': {'fundamental': {'symbol': 'AAPL',
#    'high52': 145.09,
#    'low52': 83.145,
#    'dividendAmount': 0.88,
#    'dividendYield': 0.67,
#    'dividendDate': '2021-05-07 00:00:00.000',
#    'peRatio': 29.27891,
#    'pegRatio': 0.736688,
#    'pbRatio': 31.47285,
#    'prRatio': 6.69134,
#    'pcfRatio': 24.96219,
#    'grossMarginTTM': 39.88126,
#    'grossMarginMRQ': 42.50647,
#    'netProfitMarginTTM': 23.45101,
#    'netProfitMarginMRQ': 26.37748,
#    'operatingMarginTTM': 27.32064,
#    'operatingMarginMRQ': 30.70079,
#    'returnOnEquity': 103.4003,
#    'returnOnAssets': 23.21042,
#    'returnOnInvestment': 33.53747,
#    'quickRatio': 1.09269,
#    'currentRatio': 1.14175,
#    'interestCoverage': 0.0,
#    'totalDebtToCapital': 63.74756,
#    'ltDebtToEquity': 157.047,
#    'totalDebtToEquity': 175.8435,
#    'epsTTM': 4.45645,
#    'epsChangePercentTTM': 39.744,
#    'epsChangeYear': 118.6195,
#    'epsChange': 0.0,
#    'revChangeYear': 0.0,
#    'revChangeTTM': 21.42876,
#    'revChangeIn': 0.0,
#    'sharesOutstanding': 16687631000.0,
#    'marketCapFloat': 16676.66,
#    'marketCap': 2177402.0,
#    'bookValuePerShare': 0.0,
#    'shortIntToFloat': 0.0,
#    'shortIntDayToCover': 0.0,
#    'divGrowthRate3Year': 0.0,
#    'dividendPayAmount': 0.22,
#    'dividendPayDate': '2021-05-13 00:00:00.000',
#    'beta': 1.20202,
#    'vol1DayAvg': 70226900.0,
#    'vol10DayAvg': 70226904.0,
#    'vol3MonthAvg': 1870660490.0},
#   'cusip': '037833100',
#   'symbol': 'AAPL',
#   'description': 'Apple Inc. - Common Stock',
#   'exchange': 'NASDAQ',
#   'assetType': 'EQUITY'}}

# %% [markdown]
# ### Cadena de Opciones

# %% [markdown]
# Este es el endpoint mas jugoso de la API a mi entender ya que es un dato de mercado dificil de conseguir en  formma gratuita y fidedigna esto de las cadenas de opciones

# %% [markdown]
# Les dejo la implementación en python de un llamado al endpoint de opciones sencillo que me devuelve en principio todo un json y como es muy compleja la estructura vamos trabajandola de a poco luego

# %%
import requests

def options(symbol):
    
    params = {'apikey' : c_key, 'symbol':symbol}
    
    endpoint = 'https://api.tdameritrade.com/v1/marketdata/chains'
    
    r = requests.get(url=endpoint ,params=params)
    return r.json()

chain = options('GGAL')
chain
# Out:
# {'symbol': 'GGAL',
#  'status': 'SUCCESS',
#  'underlying': None,
#  'strategy': 'SINGLE',
#  'interval': 0.0,
#  'isDelayed': True,
#  'isIndex': False,
#  'interestRate': 0.1,
#  'underlyingPrice': 9.975,
#  'volatility': 29.0,
#  'daysToExpiration': 0.0,
#  'numberOfContracts': 68,
#  'putExpDateMap': {'2021-06-18:3': {'2.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_061821P2.5',
#      'description': 'GGAL Jun 18 2021 2.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.05,
#      'last': 0.0,
#      'mark': 0.03,
#      'bidSize': 0,
#      'askSize': 242,
#      'bidAskSize': '0X242',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1623787091015,
#      'netChange': 0.0,
#      'volatility': 680.188,
#      'delta': -0.009,
#      'gamma': 0.003,
#      'theta': -0.022,
#      'vega': 0.0,
#      'rho': 0.0,
#      'openInterest': 0,
#      'timeValue': 0.03,
#      'theoreticalOptionValue': 0.025,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 2.5,
#      'expirationDate': 1624046400000,
#      'daysToExpiration': 3,
#      'expirationType': 'R',
#      'lastTradingDay': 1624060800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.02,
#      'markPercentChange': 24900.0,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '5.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_061821P5',
#      'description': 'GGAL Jun 18 2021 5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.05,
#      'last': 0.1,
#      'mark': 0.03,
#      'bidSize': 0,
#      'askSize': 230,
#      'bidAskSize': '0X230',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1622141861753,
#      'quoteTimeInLong': 1623787091018,
#      'netChange': 0.1,
#      'volatility': 358.468,
#      'delta': -0.017,
#      'gamma': 0.012,
#      'theta': -0.021,
#      'vega': 0.0,
#      'rho': 0.0,
#      'openInterest': 152,
#      'timeValue': 0.1,
#      'theoreticalOptionValue': 0.025,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 5.0,
#      'expirationDate': 1624046400000,
#      'daysToExpiration': 3,
#      'expirationType': 'R',
#      'lastTradingDay': 1624060800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 99900.0,
#      'markChange': 0.02,
#      'markPercentChange': 24900.0,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '7.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_061821P7.5',
#      'description': 'GGAL Jun 18 2021 7.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.1,
#      'last': 0.05,
#      'mark': 0.05,
#      'bidSize': 0,
#      'askSize': 150,
#      'bidAskSize': '0X150',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1622574742703,
#      'quoteTimeInLong': 1623787084497,
#      'netChange': 0.05,
#      'volatility': 194.928,
#      'delta': -0.055,
#      'gamma': 0.057,
#      'theta': -0.03,
#      'vega': 0.001,
#      'rho': 0.0,
#      'openInterest': 65,
#      'timeValue': 0.05,
#      'theoreticalOptionValue': 0.05,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 7.5,
#      'expirationDate': 1624046400000,
#      'daysToExpiration': 3,
#      'expirationType': 'R',
#      'lastTradingDay': 1624060800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 49900.0,
#      'markChange': 0.05,
#      'markPercentChange': 49900.0,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '10.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_061821P10',
#      'description': 'GGAL Jun 18 2021 10 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.15,
#      'ask': 0.25,
#      'last': 0.18,
#      'mark': 0.2,
#      'bidSize': 53,
#      'askSize': 252,
#      'bidAskSize': '53X252',
#      'lastSize': 0,
#      'highPrice': 0.2,
#      'lowPrice': 0.18,
#      'openPrice': 0.0,
#      'closePrice': 0.17,
#      'totalVolume': 13,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623786761800,
#      'quoteTimeInLong': 1623787197368,
#      'netChange': 0.0,
#      'volatility': 55.858,
#      'delta': -0.453,
#      'gamma': 0.701,
#      'theta': -0.033,
#      'vega': 0.004,
#      'rho': 0.0,
#      'openInterest': 320,
#      'timeValue': 0.18,
#      'theoreticalOptionValue': 0.2,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 10.0,
#      'expirationDate': 1624046400000,
#      'daysToExpiration': 3,
#      'expirationType': 'R',
#      'lastTradingDay': 1624060800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 2.86,
#      'markChange': 0.03,
#      'markPercentChange': 14.29,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '12.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_061821P12.5',
#      'description': 'GGAL Jun 18 2021 12.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 2.4,
#      'ask': 2.55,
#      'last': 2.7,
#      'mark': 2.47,
#      'bidSize': 20,
#      'askSize': 21,
#      'bidAskSize': '20X21',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 2.4,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623172856314,
#      'quoteTimeInLong': 1623787196164,
#      'netChange': 0.3,
#      'volatility': 126.682,
#      'delta': -0.949,
#      'gamma': 0.079,
#      'theta': -0.023,
#      'vega': 0.001,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.27,
#      'theoreticalOptionValue': 2.475,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 12.5,
#      'expirationDate': 1624046400000,
#      'daysToExpiration': 3,
#      'expirationType': 'R',
#      'lastTradingDay': 1624060800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 12.5,
#      'markChange': 0.07,
#      'markPercentChange': 3.12,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}]},
#   '2021-07-16:31': {'2.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_071621P2.5',
#      'description': 'GGAL Jul 16 2021 2.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.05,
#      'last': 0.0,
#      'mark': 0.03,
#      'bidSize': 0,
#      'askSize': 341,
#      'bidAskSize': '0X341',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1623787084454,
#      'netChange': 0.0,
#      'volatility': 232.367,
#      'delta': -0.009,
#      'gamma': 0.003,
#      'theta': -0.003,
#      'vega': 0.001,
#      'rho': 0.0,
#      'openInterest': 0,
#      'timeValue': 0.03,
#      'theoreticalOptionValue': 0.025,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 2.5,
#      'expirationDate': 1626465600000,
#      'daysToExpiration': 31,
#      'expirationType': 'R',
#      'lastTradingDay': 1626480000000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.02,
#      'markPercentChange': 24900.0,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '5.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_071621P5',
#      'description': 'GGAL Jul 16 2021 5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.25,
#      'last': 0.05,
#      'mark': 0.13,
#      'bidSize': 0,
#      'askSize': 459,
#      'bidAskSize': '0X459',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1621351296280,
#      'quoteTimeInLong': 1623787083328,
#      'netChange': 0.05,
#      'volatility': 169.55,
#      'delta': -0.049,
#      'gamma': 0.02,
#      'theta': -0.008,
#      'vega': 0.003,
#      'rho': -0.001,
#      'openInterest': 69,
#      'timeValue': 0.05,
#      'theoreticalOptionValue': 0.125,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 5.0,
#      'expirationDate': 1626465600000,
#      'daysToExpiration': 31,
#      'expirationType': 'R',
#      'lastTradingDay': 1626480000000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 49900.0,
#      'markChange': 0.12,
#      'markPercentChange': 124900.0,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '7.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_071621P7.5',
#      'description': 'GGAL Jul 16 2021 7.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.4,
#      'last': 0.1,
#      'mark': 0.2,
#      'bidSize': 0,
#      'askSize': 653,
#      'bidAskSize': '0X653',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.01,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623436442481,
#      'quoteTimeInLong': 1623787161222,
#      'netChange': 0.09,
#      'volatility': 98.703,
#      'delta': -0.122,
#      'gamma': 0.069,
#      'theta': -0.009,
#      'vega': 0.006,
#      'rho': -0.001,
#      'openInterest': 1572,
#      'timeValue': 0.1,
#      'theoreticalOptionValue': 0.2,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 7.5,
#      'expirationDate': 1626465600000,
#      'daysToExpiration': 31,
#      'expirationType': 'R',
#      'lastTradingDay': 1626480000000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 952.63,
#      'markChange': 0.19,
#      'markPercentChange': 2005.26,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '10.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_071621P10',
#      'description': 'GGAL Jul 16 2021 10 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.35,
#      'ask': 0.7,
#      'last': 0.55,
#      'mark': 0.52,
#      'bidSize': 1177,
#      'askSize': 421,
#      'bidAskSize': '1177X421',
#      'lastSize': 0,
#      'highPrice': 0.55,
#      'lowPrice': 0.55,
#      'openPrice': 0.0,
#      'closePrice': 0.51,
#      'totalVolume': 1,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623784011007,
#      'quoteTimeInLong': 1623787191046,
#      'netChange': 0.04,
#      'volatility': 48.587,
#      'delta': -0.446,
#      'gamma': 0.276,
#      'theta': -0.009,
#      'vega': 0.012,
#      'rho': -0.004,
#      'openInterest': 180,
#      'timeValue': 0.55,
#      'theoreticalOptionValue': 0.525,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 10.0,
#      'expirationDate': 1626465600000,
#      'daysToExpiration': 31,
#      'expirationType': 'R',
#      'lastTradingDay': 1626480000000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 7.17,
#      'markChange': 0.01,
#      'markPercentChange': 2.3,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '12.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_071621P12.5',
#      'description': 'GGAL Jul 16 2021 12.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 2.45,
#      'ask': 2.75,
#      'last': 4.94,
#      'mark': 2.6,
#      'bidSize': 282,
#      'askSize': 143,
#      'bidAskSize': '282X143',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 2.42,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1620847241146,
#      'quoteTimeInLong': 1623787199734,
#      'netChange': 2.52,
#      'volatility': 49.018,
#      'delta': -0.918,
#      'gamma': 0.08,
#      'theta': -0.003,
#      'vega': 0.004,
#      'rho': -0.004,
#      'openInterest': 13,
#      'timeValue': 2.51,
#      'theoreticalOptionValue': 2.454,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 12.5,
#      'expirationDate': 1626465600000,
#      'daysToExpiration': 31,
#      'expirationType': 'R',
#      'lastTradingDay': 1626480000000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 104.5,
#      'markChange': 0.18,
#      'markPercentChange': 7.63,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}],
#    '15.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_071621P15',
#      'description': 'GGAL Jul 16 2021 15 Put',
#      'exchangeName': 'OPR',
#      'bid': 4.7,
#      'ask': 5.0,
#      'last': 7.32,
#      'mark': 4.85,
#      'bidSize': 651,
#      'askSize': 20,
#      'bidAskSize': '651X20',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 4.9,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1610464856254,
#      'quoteTimeInLong': 1623787197133,
#      'netChange': 2.42,
#      'volatility': 95.633,
#      'delta': -0.899,
#      'gamma': 0.063,
#      'theta': -0.007,
#      'vega': 0.005,
#      'rho': -0.012,
#      'openInterest': 17,
#      'timeValue': 2.39,
#      'theoreticalOptionValue': 5.025,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 15.0,
#      'expirationDate': 1626465600000,
#      'daysToExpiration': 31,
#      'expirationType': 'R',
#      'lastTradingDay': 1626480000000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 49.39,
#      'markChange': -0.05,
#      'markPercentChange': -1.02,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}]},
#   '2021-10-15:122': {'2.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_101521P2.5',
#      'description': 'GGAL Oct 15 2021 2.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.05,
#      'last': 0.25,
#      'mark': 0.03,
#      'bidSize': 0,
#      'askSize': 66,
#      'bidAskSize': '0X66',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1619703035739,
#      'quoteTimeInLong': 1623787151010,
#      'netChange': 0.25,
#      'volatility': 118.549,
#      'delta': -0.009,
#      'gamma': 0.003,
#      'theta': -0.001,
#      'vega': 0.001,
#      'rho': 0.0,
#      'openInterest': 100,
#      'timeValue': 0.25,
#      'theoreticalOptionValue': 0.025,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 2.5,
#      'expirationDate': 1634328000000,
#      'daysToExpiration': 122,
#      'expirationType': 'R',
#      'lastTradingDay': 1634342400000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 62400.0,
#      'markChange': 0.02,
#      'markPercentChange': 6150.0,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '5.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_101521P5',
#      'description': 'GGAL Oct 15 2021 5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.05,
#      'last': 0.2,
#      'mark': 0.03,
#      'bidSize': 0,
#      'askSize': 2,
#      'bidAskSize': '0X2',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.02,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1620413052968,
#      'quoteTimeInLong': 1623769230692,
#      'netChange': 0.18,
#      'volatility': 62.921,
#      'delta': -0.017,
#      'gamma': 0.011,
#      'theta': -0.001,
#      'vega': 0.002,
#      'rho': -0.001,
#      'openInterest': 7,
#      'timeValue': 0.2,
#      'theoreticalOptionValue': 0.025,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 5.0,
#      'expirationDate': 1634328000000,
#      'daysToExpiration': 122,
#      'expirationType': 'R',
#      'lastTradingDay': 1634342400000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 733.33,
#      'markChange': 0.0,
#      'markPercentChange': 4.17,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '7.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_101521P7.5',
#      'description': 'GGAL Oct 15 2021 7.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.2,
#      'ask': 0.3,
#      'last': 0.29,
#      'mark': 0.25,
#      'bidSize': 222,
#      'askSize': 22,
#      'bidAskSize': '222X22',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.22,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623685008811,
#      'quoteTimeInLong': 1623787199391,
#      'netChange': 0.06,
#      'volatility': 55.021,
#      'delta': -0.134,
#      'gamma': 0.067,
#      'theta': -0.003,
#      'vega': 0.013,
#      'rho': -0.005,
#      'openInterest': 752,
#      'timeValue': 0.29,
#      'theoreticalOptionValue': 0.25,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 7.5,
#      'expirationDate': 1634328000000,
#      'daysToExpiration': 122,
#      'expirationType': 'R',
#      'lastTradingDay': 1634342400000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 28.89,
#      'markChange': 0.03,
#      'markPercentChange': 11.11,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '10.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_101521P10',
#      'description': 'GGAL Oct 15 2021 10 Put',
#      'exchangeName': 'OPR',
#      'bid': 1.05,
#      'ask': 1.3,
#      'last': 1.07,
#      'mark': 1.18,
#      'bidSize': 513,
#      'askSize': 289,
#      'bidAskSize': '513X289',
#      'lastSize': 0,
#      'highPrice': 1.16,
#      'lowPrice': 1.06,
#      'openPrice': 0.0,
#      'closePrice': 0.95,
#      'totalVolume': 318,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623786428539,
#      'quoteTimeInLong': 1623787195656,
#      'netChange': 0.12,
#      'volatility': 54.192,
#      'delta': -0.422,
#      'gamma': 0.125,
#      'theta': -0.005,
#      'vega': 0.023,
#      'rho': -0.016,
#      'openInterest': 1556,
#      'timeValue': 1.07,
#      'theoreticalOptionValue': 1.175,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 10.0,
#      'expirationDate': 1634328000000,
#      'daysToExpiration': 122,
#      'expirationType': 'R',
#      'lastTradingDay': 1634342400000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 12.64,
#      'markChange': 0.23,
#      'markPercentChange': 23.7,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '12.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_101521P12.5',
#      'description': 'GGAL Oct 15 2021 12.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 2.8,
#      'ask': 2.95,
#      'last': 2.8,
#      'mark': 2.88,
#      'bidSize': 165,
#      'askSize': 147,
#      'bidAskSize': '165X147',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 2.62,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623077128524,
#      'quoteTimeInLong': 1623787171024,
#      'netChange': 0.18,
#      'volatility': 53.388,
#      'delta': -0.705,
#      'gamma': 0.112,
#      'theta': -0.004,
#      'vega': 0.02,
#      'rho': -0.024,
#      'openInterest': 16,
#      'timeValue': 0.37,
#      'theoreticalOptionValue': 2.858,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 12.5,
#      'expirationDate': 1634328000000,
#      'daysToExpiration': 122,
#      'expirationType': 'R',
#      'lastTradingDay': 1634342400000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 6.78,
#      'markChange': 0.25,
#      'markPercentChange': 9.64,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}],
#    '15.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_101521P15',
#      'description': 'GGAL Oct 15 2021 15 Put',
#      'exchangeName': 'OPR',
#      'bid': 5.0,
#      'ask': 5.2,
#      'last': 0.0,
#      'mark': 5.1,
#      'bidSize': 26,
#      'askSize': 181,
#      'bidAskSize': '26X181',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 4.91,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1623787166506,
#      'netChange': 0.0,
#      'volatility': 52.202,
#      'delta': -0.869,
#      'gamma': 0.051,
#      'theta': -0.002,
#      'vega': 0.011,
#      'rho': -0.02,
#      'openInterest': 0,
#      'timeValue': 0.17,
#      'theoreticalOptionValue': 5.007,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 15.0,
#      'expirationDate': 1634328000000,
#      'daysToExpiration': 122,
#      'expirationType': 'R',
#      'lastTradingDay': 1634342400000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.19,
#      'markPercentChange': 3.95,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}]},
#   '2022-01-21:220': {'2.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012122P2.5',
#      'description': 'GGAL Jan 21 2022 2.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.1,
#      'last': 0.05,
#      'mark': 0.05,
#      'bidSize': 0,
#      'askSize': 159,
#      'bidAskSize': '0X159',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.04,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1622122201290,
#      'quoteTimeInLong': 1623787082586,
#      'netChange': 0.01,
#      'volatility': 99.028,
#      'delta': -0.014,
#      'gamma': 0.005,
#      'theta': -0.001,
#      'vega': 0.003,
#      'rho': -0.001,
#      'openInterest': 628,
#      'timeValue': 0.05,
#      'theoreticalOptionValue': 0.05,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 2.5,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 220,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 11.61,
#      'markChange': 0.01,
#      'markPercentChange': 11.61,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '5.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012122P5',
#      'description': 'GGAL Jan 21 2022 5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.05,
#      'ask': 0.75,
#      'last': 0.15,
#      'mark': 0.4,
#      'bidSize': 109,
#      'askSize': 499,
#      'bidAskSize': '109X499',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.2,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623253248285,
#      'quoteTimeInLong': 1623787099840,
#      'netChange': -0.05,
#      'volatility': 90.625,
#      'delta': -0.088,
#      'gamma': 0.023,
#      'theta': -0.003,
#      'vega': 0.013,
#      'rho': -0.008,
#      'openInterest': 438,
#      'timeValue': 0.15,
#      'theoreticalOptionValue': 0.4,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 5.0,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 220,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -25.0,
#      'markChange': 0.2,
#      'markPercentChange': 100.0,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '7.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012122P7.5',
#      'description': 'GGAL Jan 21 2022 7.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.45,
#      'ask': 0.5,
#      'last': 0.53,
#      'mark': 0.48,
#      'bidSize': 137,
#      'askSize': 1,
#      'bidAskSize': '137X1',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.5,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623690515284,
#      'quoteTimeInLong': 1623787151009,
#      'netChange': 0.03,
#      'volatility': 52.625,
#      'delta': -0.175,
#      'gamma': 0.063,
#      'theta': -0.002,
#      'vega': 0.02,
#      'rho': -0.013,
#      'openInterest': 3360,
#      'timeValue': 0.53,
#      'theoreticalOptionValue': 0.475,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 7.5,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 220,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 6.0,
#      'markChange': -0.03,
#      'markPercentChange': -5.0,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '10.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012122P10',
#      'description': 'GGAL Jan 21 2022 10 Put',
#      'exchangeName': 'OPR',
#      'bid': 1.15,
#      'ask': 1.95,
#      'last': 1.5,
#      'mark': 1.55,
#      'bidSize': 618,
#      'askSize': 530,
#      'bidAskSize': '618X530',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 1.6,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623685802149,
#      'quoteTimeInLong': 1623787196446,
#      'netChange': -0.1,
#      'volatility': 52.032,
#      'delta': -0.41,
#      'gamma': 0.095,
#      'theta': -0.003,
#      'vega': 0.03,
#      'rho': -0.031,
#      'openInterest': 239,
#      'timeValue': 1.5,
#      'theoreticalOptionValue': 1.55,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 10.0,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 220,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -6.25,
#      'markChange': -0.05,
#      'markPercentChange': -3.13,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '12.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012122P12.5',
#      'description': 'GGAL Jan 21 2022 12.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 3.1,
#      'ask': 3.3,
#      'last': 4.6,
#      'mark': 3.2,
#      'bidSize': 246,
#      'askSize': 26,
#      'bidAskSize': '246X26',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 3.25,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1621956266033,
#      'quoteTimeInLong': 1623787087327,
#      'netChange': 1.35,
#      'volatility': 51.657,
#      'delta': -0.63,
#      'gamma': 0.094,
#      'theta': -0.003,
#      'vega': 0.03,
#      'rho': -0.058,
#      'openInterest': 91,
#      'timeValue': 2.17,
#      'theoreticalOptionValue': 3.224,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 12.5,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 220,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 41.57,
#      'markChange': -0.05,
#      'markPercentChange': -1.51,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}],
#    '15.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012122P15',
#      'description': 'GGAL Jan 21 2022 15 Put',
#      'exchangeName': 'OPR',
#      'bid': 5.1,
#      'ask': 5.6,
#      'last': 7.73,
#      'mark': 5.35,
#      'bidSize': 306,
#      'askSize': 391,
#      'bidAskSize': '306X391',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 5.25,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1618928192439,
#      'quoteTimeInLong': 1623787193919,
#      'netChange': 2.48,
#      'volatility': 48.388,
#      'delta': -0.808,
#      'gamma': 0.073,
#      'theta': -0.002,
#      'vega': 0.022,
#      'rho': -0.081,
#      'openInterest': 59,
#      'timeValue': 2.8,
#      'theoreticalOptionValue': 5.222,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 15.0,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 220,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 47.29,
#      'markChange': 0.1,
#      'markPercentChange': 1.94,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}],
#    '17.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012122P17.5',
#      'description': 'GGAL Jan 21 2022 17.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 7.5,
#      'ask': 7.7,
#      'last': 10.55,
#      'mark': 7.6,
#      'bidSize': 136,
#      'askSize': 39,
#      'bidAskSize': '136X39',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 7.6,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1589480660620,
#      'quoteTimeInLong': 1623787197046,
#      'netChange': 2.95,
#      'volatility': 47.639,
#      'delta': -0.906,
#      'gamma': 0.047,
#      'theta': -0.001,
#      'vega': 0.014,
#      'rho': -0.101,
#      'openInterest': 1,
#      'timeValue': 3.12,
#      'theoreticalOptionValue': 7.521,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 17.5,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 220,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 38.87,
#      'markChange': 0.0,
#      'markPercentChange': 0.04,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}],
#    '20.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012122P20',
#      'description': 'GGAL Jan 21 2022 20 Put',
#      'exchangeName': 'OPR',
#      'bid': 9.9,
#      'ask': 10.1,
#      'last': 11.2,
#      'mark': 10.0,
#      'bidSize': 166,
#      'askSize': 21,
#      'bidAskSize': '166X21',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 10.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1622216013292,
#      'quoteTimeInLong': 1623787164220,
#      'netChange': 1.2,
#      'volatility': 48.567,
#      'delta': -0.951,
#      'gamma': 0.029,
#      'theta': -0.001,
#      'vega': 0.009,
#      'rho': -0.118,
#      'openInterest': 21,
#      'timeValue': 1.27,
#      'theoreticalOptionValue': 9.944,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 20.0,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 220,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 12.04,
#      'markChange': 0.0,
#      'markPercentChange': 0.04,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}],
#    '22.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012122P22.5',
#      'description': 'GGAL Jan 21 2022 22.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 12.3,
#      'ask': 12.6,
#      'last': 15.95,
#      'mark': 12.45,
#      'bidSize': 150,
#      'askSize': 20,
#      'bidAskSize': '150X20',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 12.45,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1602168252191,
#      'quoteTimeInLong': 1623787178946,
#      'netChange': 3.5,
#      'volatility': 72.988,
#      'delta': -0.874,
#      'gamma': 0.037,
#      'theta': -0.003,
#      'vega': 0.017,
#      'rho': -0.13,
#      'openInterest': 2,
#      'timeValue': 3.52,
#      'theoreticalOptionValue': 12.667,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 22.5,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 220,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 28.15,
#      'markChange': 0.0,
#      'markPercentChange': 0.03,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}]},
#   '2023-01-20:584': {'2.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012023P2.5',
#      'description': 'GGAL Jan 20 2023 2.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 1.9,
#      'last': 0.0,
#      'mark': 0.95,
#      'bidSize': 0,
#      'askSize': 156,
#      'bidAskSize': '0X156',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.05,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1623787091011,
#      'netChange': 0.0,
#      'volatility': 150.423,
#      'delta': -0.045,
#      'gamma': 0.005,
#      'theta': -0.002,
#      'vega': 0.012,
#      'rho': -0.023,
#      'openInterest': 0,
#      'timeValue': 0.95,
#      'theoreticalOptionValue': 0.95,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 2.5,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 584,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.9,
#      'markPercentChange': 1997.13,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '5.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012023P5',
#      'description': 'GGAL Jan 20 2023 5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.2,
#      'ask': 0.65,
#      'last': 0.5,
#      'mark': 0.43,
#      'bidSize': 411,
#      'askSize': 20,
#      'bidAskSize': '411X20',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.48,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623698315419,
#      'quoteTimeInLong': 1623787102305,
#      'netChange': 0.02,
#      'volatility': 61.291,
#      'delta': -0.086,
#      'gamma': 0.021,
#      'theta': -0.001,
#      'vega': 0.02,
#      'rho': -0.019,
#      'openInterest': 132,
#      'timeValue': 0.5,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 5.0,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 584,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 4.36,
#      'markChange': -0.05,
#      'markPercentChange': -11.29,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '7.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012023P7.5',
#      'description': 'GGAL Jan 20 2023 7.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 1.25,
#      'ask': 1.5,
#      'last': 1.35,
#      'mark': 1.38,
#      'bidSize': 297,
#      'askSize': 1,
#      'bidAskSize': '297X1',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 1.25,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623690266018,
#      'quoteTimeInLong': 1623787168136,
#      'netChange': 0.1,
#      'volatility': 62.771,
#      'delta': -0.206,
#      'gamma': 0.038,
#      'theta': -0.002,
#      'vega': 0.038,
#      'rho': -0.047,
#      'openInterest': 956,
#      'timeValue': 1.35,
#      'theoreticalOptionValue': 1.375,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 7.5,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 584,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 8.0,
#      'markChange': 0.13,
#      'markPercentChange': 10.0,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '10.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012023P10',
#      'description': 'GGAL Jan 20 2023 10 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.15,
#      'ask': 2.95,
#      'last': 2.5,
#      'mark': 1.55,
#      'bidSize': 696,
#      'askSize': 51,
#      'bidAskSize': '696X51',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 2.2,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623680277902,
#      'quoteTimeInLong': 1623787083120,
#      'netChange': 0.3,
#      'volatility': 39.152,
#      'delta': -0.368,
#      'gamma': 0.088,
#      'theta': -0.001,
#      'vega': 0.05,
#      'rho': -0.049,
#      'openInterest': 324,
#      'timeValue': 2.5,
#      'theoreticalOptionValue': 1.55,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 10.0,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 584,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 13.52,
#      'markChange': -0.65,
#      'markPercentChange': -29.62,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '12.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012023P12.5',
#      'description': 'GGAL Jan 20 2023 12.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 3.4,
#      'ask': 6.1,
#      'last': 5.4,
#      'mark': 4.75,
#      'bidSize': 140,
#      'askSize': 61,
#      'bidAskSize': '140X61',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 4.04,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1622059188014,
#      'quoteTimeInLong': 1623787197537,
#      'netChange': 1.36,
#      'volatility': 44.066,
#      'delta': -0.552,
#      'gamma': 0.09,
#      'theta': -0.001,
#      'vega': 0.053,
#      'rho': -0.077,
#      'openInterest': 34,
#      'timeValue': 2.97,
#      'theoreticalOptionValue': 3.383,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 12.5,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 584,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 33.74,
#      'markChange': 0.71,
#      'markPercentChange': 17.64,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}],
#    '15.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012023P15',
#      'description': 'GGAL Jan 20 2023 15 Put',
#      'exchangeName': 'OPR',
#      'bid': 4.8,
#      'ask': 8.5,
#      'last': 8.36,
#      'mark': 6.65,
#      'bidSize': 98,
#      'askSize': 60,
#      'bidAskSize': '98X60',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 6.05,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1618928192439,
#      'quoteTimeInLong': 1623787139735,
#      'netChange': 2.31,
#      'volatility': 45.552,
#      'delta': -0.702,
#      'gamma': 0.087,
#      'theta': -0.001,
#      'vega': 0.046,
#      'rho': -0.085,
#      'openInterest': 2,
#      'timeValue': 3.43,
#      'theoreticalOptionValue': 5.403,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 15.0,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 584,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 38.18,
#      'markChange': 0.6,
#      'markPercentChange': 9.92,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}],
#    '17.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012023P17.5',
#      'description': 'GGAL Jan 20 2023 17.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 8.2,
#      'ask': 10.5,
#      'last': 9.35,
#      'mark': 9.35,
#      'bidSize': 87,
#      'askSize': 197,
#      'bidAskSize': '87X197',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 8.07,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1622059162141,
#      'quoteTimeInLong': 1623787085505,
#      'netChange': 1.28,
#      'volatility': 43.455,
#      'delta': -0.867,
#      'gamma': 0.085,
#      'theta': -0.001,
#      'vega': 0.027,
#      'rho': -0.057,
#      'openInterest': 32,
#      'timeValue': 1.92,
#      'theoreticalOptionValue': 7.529,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 17.5,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 584,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 15.86,
#      'markChange': 1.28,
#      'markPercentChange': 15.86,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}],
#    '20.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012023P20',
#      'description': 'GGAL Jan 20 2023 20 Put',
#      'exchangeName': 'OPR',
#      'bid': 8.4,
#      'ask': 12.6,
#      'last': 13.93,
#      'mark': 10.5,
#      'bidSize': 340,
#      'askSize': 61,
#      'bidAskSize': '340X61',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 10.31,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1602270613522,
#      'quoteTimeInLong': 1623787082713,
#      'netChange': 3.62,
#      'volatility': 45.485,
#      'delta': -0.932,
#      'gamma': 0.066,
#      'theta': 0.0,
#      'vega': 0.011,
#      'rho': -0.047,
#      'openInterest': 0,
#      'timeValue': 4.0,
#      'theoreticalOptionValue': 9.942,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 20.0,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 584,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 35.09,
#      'markChange': 0.19,
#      'markPercentChange': 1.83,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}]}},
#  'callExpDateMap': {'2021-06-18:3': {'2.5': [{'putCall': 'CALL',
#      'symbol': 'GGAL_061821C2.5',
#      'description': 'GGAL Jun 18 2021 2.5 Call',
#      'exchangeName': 'OPR',
#      'bid': 7.4,
#      'ask': 8.2,
#      'last': 0.0,
#      'mark': 7.8,
#      'bidSize': 239,
#      'askSize': 60,
#      'bidAskSize': '239X60',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 7.61,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1623787187683,
#      'netChange': 0.0,
#      'volatility': 680.188,
#      'delta': 0.989,
#      'gamma': 0.003,
#      'theta': -0.017,
#      'vega': 0.0,
#      'rho': 0.0,
#      'openInterest': 0,
#      'timeValue': 0.23,
#      'theoreticalOptionValue': 7.575,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 2.5,
#      'expirationDate': 1624046400000,
#      'daysToExpiration': 3,
#      'expirationType': 'R',
#      'lastTradingDay': 1624060800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.19,
#      'markPercentChange': 2.48,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}],
#    '5.0': [{'putCall': 'CALL',
#      'symbol': 'GGAL_061821C5',
#      'description': 'GGAL Jun 18 2021 5 Call',
#      'exchangeName': 'OPR',
#      'bid': 5.0,
#      'ask': 5.3,
#      'last': 5.2,
#      'mark': 5.15,
#      'bidSize': 20,
#      'askSize': 70,
#      'bidAskSize': '20X70',
#      'lastSize': 0,
#      'highPrice': 5.2,
#      'lowPrice': 5.2,
#      'openPrice': 0.0,
#      'closePrice': 5.11,
#      'totalVolume': 1,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623765765401,
#      'quoteTimeInLong': 1623787195304,
#      'netChange': 0.09,
#      'volatility': 358.468,
#      'delta': 0.981,
#      'gamma': 0.012,
#      'theta': -0.015,
#      'vega': 0.0,
#      'rho': 0.0,
#      'openInterest': 4,
#      'timeValue': 0.13,
#      'theoreticalOptionValue': 5.075,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 5.0,
#      'expirationDate': 1624046400000,
#      'daysToExpiration': 3,
#      'expirationType': 'R',
#      'lastTradingDay': 1624060800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 1.73,
#      'markChange': 0.04,
#      'markPercentChange': 0.76,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}],
#    '7.5': [{'putCall': 'CALL',
#      'symbol': 'GGAL_061821C7.5',
#      'description': 'GGAL Jun 18 2021 7.5 Call',
#      'exchangeName': 'OPR',
#      'bid': 2.5,
#      'ask': 2.8,
#      'last': 3.0,
#      'mark': 2.65,
#      'bidSize': 204,
#      'askSize': 259,
#      'bidAskSize': '204X259',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 2.61,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623334413588,
#      'quoteTimeInLong': 1623787199230,
#      'netChange': 0.39,
#      'volatility': 194.928,
#      'delta': 0.943,
#      'gamma': 0.057,
#      'theta': -0.025,
#      'vega': 0.001,
#      'rho': 0.001,
#      'openInterest': 423,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 2.6,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 7.5,
#      'expirationDate': 1624046400000,
#      'daysToExpiration': 3,
#      'expirationType': 'R',
#      'lastTradingDay': 1624060800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 14.88,
#      'markChange': 0.04,
#      'markPercentChange': 1.48,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}],
#    '10.0': [{'putCall': 'CALL',
#      'symbol': 'GGAL_061821C10',
#      'description': 'GGAL Jun 18 2021 10 Call',
#      'exchangeName': 'OPR',
#      'bid': 0.2,
#      'ask': 0.3,
#      'last': 0.15,
#      'mark': 0.25,
#      'bidSize': 194,
#      'askSize': 16,
#      'bidAskSize': '194X16',
#      'lastSize': 0,
#      'highPrice': 0.2,
#      'lowPrice': 0.15,
#      'openPrice': 0.0,
#      'closePrice': 0.29,
#      'totalVolume': 529,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623781167020,
#      'quoteTimeInLong': 1623787199798,
#      'netChange': -0.14,
#      'volatility': 55.858,
#      'delta': 0.548,
#      'gamma': 0.712,
#      'theta': -0.028,
#      'vega': 0.004,
#      'rho': 0.0,
#      'openInterest': 742,
#      'timeValue': 0.08,
#      'theoreticalOptionValue': 0.251,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 10.0,
# ...
#      'quoteTimeInLong': 1623787154428,
#      'netChange': 0.0,
#      'volatility': 51.657,
#      'delta': 0.375,
#      'gamma': 0.094,
#      'theta': -0.004,
#      'vega': 0.03,
#      'rho': 0.018,
#      'openInterest': 807,
#      'timeValue': 0.85,
#      'theoreticalOptionValue': 0.85,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 12.5,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 220,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.0,
#      'markPercentChange': 0.0,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '15.0': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012122C15',
#      'description': 'GGAL Jan 21 2022 15 Call',
#      'exchangeName': 'OPR',
#      'bid': 0.25,
#      'ask': 0.45,
#      'last': 0.35,
#      'mark': 0.35,
#      'bidSize': 448,
#      'askSize': 186,
#      'bidAskSize': '448X186',
#      'lastSize': 0,
#      'highPrice': 0.35,
#      'lowPrice': 0.35,
#      'openPrice': 0.0,
#      'closePrice': 0.35,
#      'totalVolume': 20,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623775874703,
#      'quoteTimeInLong': 1623787171029,
#      'netChange': 0.0,
#      'volatility': 48.388,
#      'delta': 0.197,
#      'gamma': 0.073,
#      'theta': -0.002,
#      'vega': 0.022,
#      'rho': 0.01,
#      'openInterest': 1622,
#      'timeValue': 0.35,
#      'theoreticalOptionValue': 0.35,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 15.0,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 220,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.0,
#      'markPercentChange': 0.0,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '17.5': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012122C17.5',
#      'description': 'GGAL Jan 21 2022 17.5 Call',
#      'exchangeName': 'OPR',
#      'bid': 0.1,
#      'ask': 0.2,
#      'last': 0.2,
#      'mark': 0.15,
#      'bidSize': 420,
#      'askSize': 10,
#      'bidAskSize': '420X10',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.2,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623695130746,
#      'quoteTimeInLong': 1623787099241,
#      'netChange': 0.0,
#      'volatility': 47.639,
#      'delta': 0.099,
#      'gamma': 0.047,
#      'theta': -0.001,
#      'vega': 0.014,
#      'rho': 0.005,
#      'openInterest': 1785,
#      'timeValue': 0.2,
#      'theoreticalOptionValue': 0.15,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 17.5,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 220,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': -0.05,
#      'markPercentChange': -25.0,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '20.0': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012122C20',
#      'description': 'GGAL Jan 21 2022 20 Call',
#      'exchangeName': 'OPR',
#      'bid': 0.05,
#      'ask': 0.1,
#      'last': 0.1,
#      'mark': 0.08,
#      'bidSize': 44,
#      'askSize': 10,
#      'bidAskSize': '44X10',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.1,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623088233219,
#      'quoteTimeInLong': 1623787096189,
#      'netChange': 0.0,
#      'volatility': 48.567,
#      'delta': 0.053,
#      'gamma': 0.029,
#      'theta': -0.001,
#      'vega': 0.009,
#      'rho': 0.003,
#      'openInterest': 1012,
#      'timeValue': 0.1,
#      'theoreticalOptionValue': 0.075,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 20.0,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 220,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': -0.03,
#      'markPercentChange': -25.0,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '22.5': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012122C22.5',
#      'description': 'GGAL Jan 21 2022 22.5 Call',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.6,
#      'last': 0.2,
#      'mark': 0.3,
#      'bidSize': 0,
#      'askSize': 477,
#      'bidAskSize': '0X477',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.05,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1613055878878,
#      'quoteTimeInLong': 1623787093943,
#      'netChange': 0.15,
#      'volatility': 72.988,
#      'delta': 0.131,
#      'gamma': 0.037,
#      'theta': -0.003,
#      'vega': 0.017,
#      'rho': 0.006,
#      'openInterest': 448,
#      'timeValue': 0.2,
#      'theoreticalOptionValue': 0.3,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 22.5,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 220,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 293.7,
#      'markChange': 0.25,
#      'markPercentChange': 490.55,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}]},
#   '2023-01-20:584': {'2.5': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012023C2.5',
#      'description': 'GGAL Jan 20 2023 2.5 Call',
#      'exchangeName': 'OPR',
#      'bid': 5.6,
#      'ask': 9.3,
#      'last': 7.25,
#      'mark': 7.45,
#      'bidSize': 60,
#      'askSize': 60,
#      'bidAskSize': '60X60',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 7.95,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1622729042578,
#      'quoteTimeInLong': 1623787170732,
#      'netChange': -0.7,
#      'volatility': 150.423,
#      'delta': 1.07,
#      'gamma': 0.005,
#      'theta': -0.004,
#      'vega': 0.012,
#      'rho': 0.017,
#      'openInterest': 4,
#      'timeValue': -0.32,
#      'theoreticalOptionValue': 9.687,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 2.5,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 584,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -8.76,
#      'markChange': -0.5,
#      'markPercentChange': -6.25,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}],
#    '5.0': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012023C5',
#      'description': 'GGAL Jan 20 2023 5 Call',
#      'exchangeName': 'OPR',
#      'bid': 5.2,
#      'ask': 7.3,
#      'last': 5.88,
#      'mark': 6.25,
#      'bidSize': 20,
#      'askSize': 150,
#      'bidAskSize': '20X150',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 5.88,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623335970629,
#      'quoteTimeInLong': 1623787100060,
#      'netChange': 0.0,
#      'volatility': 61.291,
#      'delta': 1.031,
#      'gamma': 0.02,
#      'theta': -0.003,
#      'vega': 0.02,
#      'rho': 0.06,
#      'openInterest': 223,
#      'timeValue': 0.81,
#      'theoreticalOptionValue': 6.663,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 5.0,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 584,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -0.05,
#      'markChange': 0.37,
#      'markPercentChange': 6.24,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}],
#    '7.5': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012023C7.5',
#      'description': 'GGAL Jan 20 2023 7.5 Call',
#      'exchangeName': 'OPR',
#      'bid': 3.3,
#      'ask': 5.6,
#      'last': 4.31,
#      'mark': 4.45,
#      'bidSize': 193,
#      'askSize': 141,
#      'bidAskSize': '193X141',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 4.15,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623254449244,
#      'quoteTimeInLong': 1623787195881,
#      'netChange': 0.16,
#      'volatility': 62.771,
#      'delta': 0.912,
#      'gamma': 0.037,
#      'theta': -0.004,
#      'vega': 0.038,
#      'rho': 0.065,
#      'openInterest': 64,
#      'timeValue': 1.74,
#      'theoreticalOptionValue': 5.106,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 7.5,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 584,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 3.74,
#      'markChange': 0.3,
#      'markPercentChange': 7.11,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}],
#    '10.0': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012023C10',
#      'description': 'GGAL Jan 20 2023 10 Call',
#      'exchangeName': 'OPR',
#      'bid': 2.5,
#      'ask': 3.1,
#      'last': 2.6,
#      'mark': 2.8,
#      'bidSize': 218,
#      'askSize': 20,
#      'bidAskSize': '218X20',
#      'lastSize': 0,
#      'highPrice': 2.6,
#      'lowPrice': 2.6,
#      'openPrice': 0.0,
#      'closePrice': 2.6,
#      'totalVolume': 1,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623772262057,
#      'quoteTimeInLong': 1623787087858,
#      'netChange': 0.0,
#      'volatility': 39.152,
#      'delta': 0.766,
#      'gamma': 0.079,
#      'theta': -0.003,
#      'vega': 0.05,
#      'rho': 0.079,
#      'openInterest': 1891,
#      'timeValue': 2.53,
#      'theoreticalOptionValue': 2.757,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 10.0,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 584,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.2,
#      'markPercentChange': 7.69,
#      'inTheMoney': True,
#      'mini': False,
#      'nonStandard': False}],
#    '12.5': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012023C12.5',
#      'description': 'GGAL Jan 20 2023 12.5 Call',
#      'exchangeName': 'OPR',
#      'bid': 1.8,
#      'ask': 2.25,
#      'last': 2.0,
#      'mark': 2.03,
#      'bidSize': 2,
#      'askSize': 128,
#      'bidAskSize': '2X128',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 1.92,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623423900810,
#      'quoteTimeInLong': 1623787055303,
#      'netChange': 0.08,
#      'volatility': 44.066,
#      'delta': 0.598,
#      'gamma': 0.079,
#      'theta': -0.003,
#      'vega': 0.056,
#      'rho': 0.064,
#      'openInterest': 829,
#      'timeValue': 2.0,
#      'theoreticalOptionValue': 2.025,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 12.5,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 584,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 3.9,
#      'markChange': 0.1,
#      'markPercentChange': 5.19,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '15.0': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012023C15',
#      'description': 'GGAL Jan 20 2023 15 Call',
#      'exchangeName': 'OPR',
#      'bid': 1.2,
#      'ask': 1.7,
#      'last': 1.4,
#      'mark': 1.45,
#      'bidSize': 10,
#      'askSize': 20,
#      'bidAskSize': '10X20',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 1.42,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623438345108,
#      'quoteTimeInLong': 1623787190872,
#      'netChange': -0.03,
#      'volatility': 45.552,
#      'delta': 0.465,
#      'gamma': 0.075,
#      'theta': -0.003,
#      'vega': 0.055,
#      'rho': 0.052,
#      'openInterest': 304,
#      'timeValue': 1.4,
#      'theoreticalOptionValue': 1.45,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 15.0,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 584,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -1.75,
#      'markChange': 0.03,
#      'markPercentChange': 1.75,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '17.5': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012023C17.5',
#      'description': 'GGAL Jan 20 2023 17.5 Call',
#      'exchangeName': 'OPR',
#      'bid': 0.7,
#      'ask': 1.1,
#      'last': 1.2,
#      'mark': 0.9,
#      'bidSize': 448,
#      'askSize': 20,
#      'bidAskSize': '448X20',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.93,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623337198112,
#      'quoteTimeInLong': 1623787167772,
#      'netChange': 0.28,
#      'volatility': 43.455,
#      'delta': 0.333,
#      'gamma': 0.07,
#      'theta': -0.002,
#      'vega': 0.049,
#      'rho': 0.039,
#      'openInterest': 559,
#      'timeValue': 1.2,
#      'theoreticalOptionValue': 0.9,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 17.5,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 584,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 29.73,
#      'markChange': -0.03,
#      'markPercentChange': -2.7,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}],
#    '20.0': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012023C20',
#      'description': 'GGAL Jan 20 2023 20 Call',
#      'exchangeName': 'OPR',
#      'bid': 0.45,
#      'ask': 0.95,
#      'last': 0.6,
#      'mark': 0.7,
#      'bidSize': 378,
#      'askSize': 125,
#      'bidAskSize': '378X125',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.65,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1623430875447,
#      'quoteTimeInLong': 1623787195148,
#      'netChange': -0.05,
#      'volatility': 45.485,
#      'delta': 0.266,
#      'gamma': 0.06,
#      'theta': -0.002,
#      'vega': 0.044,
#      'rho': 0.032,
#      'openInterest': 1063,
#      'timeValue': 0.6,
#      'theoreticalOptionValue': 0.7,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 20.0,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 584,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -7.69,
#      'markChange': 0.05,
#      'markPercentChange': 7.69,
#      'inTheMoney': False,
#      'mini': False,
#      'nonStandard': False}]}}}

# %% [markdown]
# Lo que me devuelve es una estructura mas o menos asi:
#
#
# {'symbol': 'GGAL',<br>
#  'status': 'SUCCESS',<br>
#  'underlying': None,<br>
#  'strategy': 'SINGLE',<br>
#  'interval': 0.0,<br>
#  'isDelayed': True,<br>
#  'isIndex': False,<br>
#  'interestRate': 0.1,<br>
#  'underlyingPrice': 11.41,<br>
#  'volatility': 29.0,<br>
#  'daysToExpiration': 0.0,<br>
#  'numberOfContracts': 120,<br>
#  'putExpDateMap': {'2020-07-17:0': {'2.5': [.. y aca todas las claves de ese strike de ese vencimiento de ese side(put)
#
#  ... y asi los (en este caso 60) puts, y luego lo mismo para los 60 calls

# %% [markdown]
# Como esa estructura es demasiado rebuscada para listar, calcular, graficar, etc, vamos mejor a crear listados de fechas de vencimientos y de contratos por un lado y luego vamos a ir metiendolo en un dataFrame

# %%
v_calls = list(chain['callExpDateMap'].values())
v_calls_fechas = list(chain['callExpDateMap'].keys())
v_puts = list(chain['putExpDateMap'].values())
v_puts_fechas = list(chain['putExpDateMap'].keys())

print(v_calls_fechas)
# Out:
# ['2021-06-18:3', '2021-07-16:31', '2021-10-15:122', '2022-01-21:220', '2023-01-20:584']

# %% [markdown]
# Bueno, como vemos ahi ya tenemos los vencimientos y los contratos, ahora resta recorrer esas listas y meter la data en un frame

# %%
v_calls = list(chain['callExpDateMap'].values())
v_calls_fechas = list(chain['callExpDateMap'].keys())
v_puts = list(chain['putExpDateMap'].values())
v_puts_fechas = list(chain['putExpDateMap'].keys())

calls = []
for i in range(len(v_calls)):
    v = list(v_calls[i].values())    
    for j in range(len(v)):
        calls.append(v[j][0])

puts = []
for i in range(len(v_puts)):
    v = list(v_puts[i].values())    
    for j in range(len(v)):
        puts.append(v[j][0])
        
contracts = pd.concat([pd.DataFrame(calls),pd.DataFrame(puts)])
contracts.columns
# Out:
# Index(['putCall', 'symbol', 'description', 'exchangeName', 'bid', 'ask',
#        'last', 'mark', 'bidSize', 'askSize', 'bidAskSize', 'lastSize',
#        'highPrice', 'lowPrice', 'openPrice', 'closePrice', 'totalVolume',
#        'tradeDate', 'tradeTimeInLong', 'quoteTimeInLong', 'netChange',
#        'volatility', 'delta', 'gamma', 'theta', 'vega', 'rho', 'openInterest',
#        'timeValue', 'theoreticalOptionValue', 'theoreticalVolatility',
#        'optionDeliverablesList', 'strikePrice', 'expirationDate',
#        'daysToExpiration', 'expirationType', 'lastTradingDay', 'multiplier',
#        'settlementType', 'deliverableNote', 'isIndexOption', 'percentChange',
#        'markChange', 'markPercentChange', 'inTheMoney', 'mini', 'nonStandard'],
#       dtype='object')

# %%
contracts
# Out:
#    putCall            symbol                 description exchangeName   bid  \
# 0     CALL   GGAL_061821C2.5   GGAL Jun 18 2021 2.5 Call          OPR  7.40
# 1     CALL     GGAL_061821C5     GGAL Jun 18 2021 5 Call          OPR  5.00
# 2     CALL   GGAL_061821C7.5   GGAL Jun 18 2021 7.5 Call          OPR  2.50
# 3     CALL    GGAL_061821C10    GGAL Jun 18 2021 10 Call          OPR  0.20
# 4     CALL  GGAL_061821C12.5  GGAL Jun 18 2021 12.5 Call          OPR  0.00
# ..     ...               ...                         ...          ...   ...
# 29     PUT    GGAL_012023P10     GGAL Jan 20 2023 10 Put          OPR  0.15
# 30     PUT  GGAL_012023P12.5   GGAL Jan 20 2023 12.5 Put          OPR  3.40
# 31     PUT    GGAL_012023P15     GGAL Jan 20 2023 15 Put          OPR  4.80
# 32     PUT  GGAL_012023P17.5   GGAL Jan 20 2023 17.5 Put          OPR  8.20
# 33     PUT    GGAL_012023P20     GGAL Jan 20 2023 20 Put          OPR  8.40
#
#       ask   last   mark  bidSize  askSize  ... multiplier  settlementType  \
# 0    8.20   0.00   7.80      239       60  ...      100.0
# 1    5.30   5.20   5.15       20       70  ...      100.0
# 2    2.80   3.00   2.65      204      259  ...      100.0
# 3    0.30   0.15   0.25      194       16  ...      100.0
# 4    0.05   0.05   0.03        0      194  ...      100.0
# ..    ...    ...    ...      ...      ...  ...        ...             ...
# 29   2.95   2.50   1.55      696       51  ...      100.0
# 30   6.10   5.40   4.75      140       61  ...      100.0
# 31   8.50   8.36   6.65       98       60  ...      100.0
# 32  10.50   9.35   9.35       87      197  ...      100.0
# 33  12.60  13.93  10.50      340       61  ...      100.0
#
#     deliverableNote  isIndexOption  percentChange  markChange  \
# 0                             None           0.00        0.19
# 1                             None           1.73        0.04
# 2                             None          14.88        0.04
# 3                             None         -47.55       -0.04
# 4                             None       49900.00        0.02
# ..              ...            ...            ...         ...
# 29                            None          13.52       -0.65
# 30                            None          33.74        0.71
# 31                            None          38.18        0.60
# 32                            None          15.86        1.28
# 33                            None          35.09        0.19
#
#     markPercentChange inTheMoney   mini  nonStandard
# 0                2.48       True  False        False
# 1                0.76       True  False        False
# 2                1.48       True  False        False
# 3              -12.59       True  False        False
# 4            24900.00      False  False        False
# ..                ...        ...    ...          ...
# 29             -29.62      False  False        False
# 30              17.64       True  False        False
# 31               9.92       True  False        False
# 32              15.86       True  False        False
# 33               1.83       True  False        False
#
# [68 rows x 47 columns]

# %%
contracts.transpose().iloc[:,0]
# Out:
# putCall                                        CALL
# symbol                              GGAL_061821C2.5
# description               GGAL Jun 18 2021 2.5 Call
# exchangeName                                    OPR
# bid                                             7.2
# ask                                             7.4
# last                                              0
# mark                                            7.3
# bidSize                                         167
# askSize                                          20
# bidAskSize                                   167X20
# lastSize                                          0
# highPrice                                         0
# lowPrice                                          0
# openPrice                                         0
# closePrice                                     7.61
# totalVolume                                       0
# tradeDate                                      None
# tradeTimeInLong                                   0
# quoteTimeInLong                       1623773767392
# netChange                                         0
# volatility                                   671.85
# delta                                         0.991
# gamma                                         0.004
# theta                                         -0.02
# vega                                              0
# rho                                               0
# openInterest                                      0
# timeValue                                     -0.03
# theoreticalOptionValue                         7.35
# theoreticalVolatility                            29
# optionDeliverablesList                         None
# strikePrice                                     2.5
# expirationDate                        1624046400000
# daysToExpiration                                  3
# expirationType                                    R
# lastTradingDay                        1624060800000
# multiplier                                      100
# settlementType
# deliverableNote
# isIndexOption                                  None
# percentChange                                     0
# markChange                                    -0.31
# markPercentChange                             -4.09
# nonStandard                                   False
# inTheMoney                                     True
# mini                                          False
# Name: 0, dtype: object

# %% [markdown]
# Como la cantidad de columnas es muy grande, armamos una tabla cualquiera para mostrar mas columnas

# %%
tabla = contracts.loc[contracts.daysToExpiration > 0]

tabla = tabla.loc[:,['strikePrice','daysToExpiration','putCall','bid','ask',
                     'last','volatility','openInterest',
                     'theoreticalOptionValue']]

tabla.columns = ['Strike','Dias','Tipo','Bid','Ask',
                  'Ultimo','VI','OpenInt','PrimaT']
tabla
# Out:
#     Strike  Dias  Tipo   Bid    Ask  Ultimo       VI  OpenInt  PrimaT
# 0      2.5     3  CALL  7.40   8.20    0.00  680.188        0   7.575
# 1      5.0     3  CALL  5.00   5.30    5.20  358.468        4   5.075
# 2      7.5     3  CALL  2.50   2.80    3.00  194.928      423   2.600
# 3     10.0     3  CALL  0.20   0.30    0.15   55.858      742   0.251
# 4     12.5     3  CALL  0.00   0.05    0.05  126.682      109   0.025
# ..     ...   ...   ...   ...    ...     ...      ...      ...     ...
# 29    10.0   584   PUT  0.15   2.95    2.50   39.152      324   1.550
# 30    12.5   584   PUT  3.40   6.10    5.40   44.066       34   3.383
# 31    15.0   584   PUT  4.80   8.50    8.36   45.552        2   5.403
# 32    17.5   584   PUT  8.20  10.50    9.35   43.455       32   7.529
# 33    20.0   584   PUT  8.40  12.60   13.93   45.485        0   9.942
#
# [68 rows x 9 columns]

# %%
import requests, numpy as np, pandas as pd, matplotlib.pyplot as plt
from scipy import interpolate
import matplotlib.pyplot as plt

# %matplotlib inline

#saquen su API key en https://developer.tdameritrade.com/content/getting-started
c_key = 'AHTVCOTFYX2LZZF5MEEFVD668VD64GQT'


def options(symbol):
    params = {'apikey' : c_key, 'symbol':symbol}
    endpoint = 'https://api.tdameritrade.com/v1/marketdata/chains'
    r = requests.get(url=endpoint ,params=params)
    return r.json()


def optionsDF(chain, k_min=0, k_max=1000, ttm_min=10, ttm_max=700):
    v_calls = list(chain['callExpDateMap'].values())
    v_puts = list(chain['putExpDateMap'].values())
    calls, puts = [], []

    for i in range(len(v_calls)):
        v = list(v_calls[i].values())    
        for j in range(len(v)):
            calls.append(v[j][0])

    for i in range(len(v_puts)):
        v = list(v_puts[i].values())    
        for j in range(len(v)):
            puts.append(v[j][0])

    contracts = pd.concat([pd.DataFrame(calls),pd.DataFrame(puts)])
    tabla = contracts.loc[contracts.daysToExpiration>0].copy()
    tabla['ticker'] = chain['symbol']        
    df_ok = tabla.loc[(tabla['strikePrice'] > k_min) & (tabla['strikePrice'] < k_max)]
    df_ok = df_ok.loc[(df_ok['daysToExpiration'] > ttm_min) & (df_ok['daysToExpiration'] < ttm_max)]   
    return df_ok


def prepararMalla(columna, df, leg=None):
    if leg:
        df = df.loc[df['putCall']==leg].copy()
        
    df_ok = df.loc[:,['strikePrice','daysToExpiration',columna]]
    df_ok = df_ok.replace('NaN',np.nan).dropna()    
    x_q = len(df_ok['strikePrice'].unique())
    y_q = len(df_ok['daysToExpiration'].unique())
    x1 = np.linspace(df_ok['strikePrice'].min(), df_ok['strikePrice'].max(), x_q)
    y1 = np.linspace(df_ok['daysToExpiration'].min(), df_ok['daysToExpiration'].max(), y_q)
    X, Y = np.meshgrid(x1, y1)
    Z = interpolate.griddata((df_ok['strikePrice'], df_ok['daysToExpiration']), df_ok[columna], (X, Y))
    return X,Y,Z, df_ok

def grafCols(cols, leg=None, size=(16,5)):
    fig = plt.figure(figsize=size)
    ax = [fig.add_subplot(1, len(cols), i+1, projection='3d') for i in range(len(cols))]
    for i in range(len(cols)):
        col = cols[i]
        df_greeks = data.copy()
        X,Y,Z,df = prepararMalla(col, df_greeks, leg=leg)    
        ax[i].plot_wireframe(X, Y, Z, color='tab:blue', lw=2)     
        ax[i].set_title(f'{col} ({leg})', fontsize=16, color='k')
        ax[i].set_xlabel('Strikes', fontsize=16, color='k')
        ax[i].set_ylabel('TTM', fontsize=16, color='k')
        ax[i].set_zlabel(col, fontsize=16, color='k')
        ax[i].w_xaxis.set_pane_color((0,0,0,0))
        ax[i].w_yaxis.set_pane_color((0,0,0,0))
        ax[i].w_zaxis.set_pane_color((0,0,0,0))

ticker = 'AAPL'
data = optionsDF(options(ticker), k_min=80, k_max=180, ttm_min=15, ttm_max=365)
grafCols(['delta','gamma'], 'CALL')
grafCols(['vega','theta'], 'CALL')
grafCols(['rho','volatility'], 'CALL')
grafCols(['percentChange','openInterest'], 'CALL')
grafCols(['timeValue','theoreticalOptionValue'], 'CALL')
grafCols(['timeValue','theoreticalOptionValue'], 'PUT')
plt.show()

# %%
# %matplotlib notebook

ticker = 'AAPL'
data = optionsDF(options(ticker), k_min=80, k_max=180, ttm_min=15, ttm_max=365)
grafCols(['theta'], 'CALL', size=(10,8))
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
# %matplotlib inline

# %% [markdown]
# # Otras APIs
#
# * MarketStack
# * Finnhub
# * IEX
# * FMP
# * Tiingo
#
#
#
# * ROFEX
# * BYMA- IOL
# * ALPACA

# %% [markdown]
# Links a APIs recomendadas
#
#
# https://marketstack.com/
#
#
# https://financialmodelingprep.com/
#
#
# https://api.tiingo.com/documentation/general/
#
#
# https://finnhub.io/
#
#
# https://iexcloud.io/

# %% [markdown]
# Para interesados en patrones y AT
#
# https://taapi.io/indicators/

# %% [markdown]
# Recomendada para testear bots en equity
#
#
# https://alpaca.markets/

# %% [markdown]
# Recomendadas para Crypto
#
#
# * hitbtc
# * binance
# * ftx
# * cryptocompare

# %% [markdown]
# # Alpaca

# %% [markdown]
# Registrarse:
#
#
# https://alpaca.markets/

# %% [markdown]
# Documentacion:
#
#
# https://alpaca.markets/docs/

# %%
import requests
from keys_alpaca import *


api_key = 'PKZDH9QJJM3DK89VH8G6'
secret_key = 'XbnhYLgNIEFDpF10WEzk1VU72iNfo6DPfbjPtpyr'
api_key
# Out:
# 'PKZDH9QJJM3DK89VH8G6'

# %%
def getAccount():    
    
    headers ={"APCA-API-KEY-ID" : api_key, "APCA-API-SECRET-KEY":secret_key}
    endpoint = "https://paper-api.alpaca.markets/v2/account"
    
    r = requests.get(url = endpoint, headers = headers)
    
    js = r.json()
    return js

# %%
cuenta  = getAccount()
cuenta
# Out:
# {'id': '97614022-5e4d-430b-b38b-23eef3d22203',
#  'account_number': 'PA3RS8C1PEE4',
#  'status': 'ACTIVE',
#  'currency': 'USD',
#  'buying_power': '400000',
#  'regt_buying_power': '200000',
#  'daytrading_buying_power': '400000',
#  'cash': '100000',
#  'portfolio_value': '100000',
#  'pattern_day_trader': False,
#  'trading_blocked': False,
#  'transfers_blocked': False,
#  'account_blocked': False,
#  'created_at': '2021-06-15T23:56:01.495555Z',
#  'trade_suspended_by_user': False,
#  'multiplier': '4',
#  'shorting_enabled': True,
#  'equity': '100000',
#  'last_equity': '100000',
#  'long_market_value': '0',
#  'short_market_value': '0',
#  'initial_margin': '0',
#  'maintenance_margin': '0',
#  'last_maintenance_margin': '0',
#  'sma': '0',
#  'daytrade_count': 0}

# %%
cuenta.keys()
# Out:
# dict_keys(['id', 'account_number', 'status', 'currency', 'buying_power', 'regt_buying_power', 'daytrading_buying_power', 'cash', 'portfolio_value', 'pattern_day_trader', 'trading_blocked', 'transfers_blocked', 'account_blocked', 'created_at', 'trade_suspended_by_user', 'multiplier', 'shorting_enabled', 'equity', 'last_equity', 'long_market_value', 'short_market_value', 'initial_margin', 'maintenance_margin', 'last_maintenance_margin', 'sma', 'daytrade_count'])

# %% [markdown]
# ## MarketData

# %% [markdown]
# Vamos a ver como pedimos marketData con esta API, empecemos por la data histórica, le vamos a tener que pasar dos parámetros a la API:
#    * TimeFrame
#        * 1Min
#        * 5Min
#        * 15Min
#        * 1D (day)
#    * Symbolo/Simbolos

# %%
tickers = 'AAPL,MSFT'
tickers = tickers.split(",")
tickers
# Out:
# ['AAPL', 'MSFT']

# %%
lista = ['GGAL','AAPL','AMZN']
','.join(lista)
# Out:
# 'GGAL,AAPL,AMZN'

# %%
import datetime as dt
import pandas as pd

def getHistory(symbol, start, end, timeframe='1D'):    
    
    
    start = dt.datetime.strftime(start, format='%Y-%m-%dT%T-04:00')
    end = dt.datetime.strftime(end, format='%Y-%m-%dT%T-04:00')

    headers ={"APCA-API-KEY-ID" : api_key, "APCA-API-SECRET-KEY":secret_key}
    params =  {'symbols' : symbol, 'start':start, 'end':end}
    endpoint = "https://data.alpaca.markets/v1/bars/"+timeframe
    
    r = requests.get(url = endpoint, headers =headers, params=params)
    
    js = r.json()
    
    tickers = symbol.split(",")
    dfs = {}
    for ticker in tickers:
        dfs[ticker] = pd.DataFrame(js[ticker])
        dfs[ticker].t = pd.to_datetime(dfs[ticker].t, unit='s')
    return dfs

# %%
start = dt.datetime(2020,7,1,0,0,0)
end = dt.datetime(2020,10,1,0,0,0)

dfs = getHistory('AAPL,MSFT', start, end, timeframe='day')
dfs['AAPL']
# Out:
#                      t       o       h       l       c          v
# 0  2020-07-01 04:00:00  365.12  367.36  363.91  364.01   25429807
# 1  2020-07-02 04:00:00  367.85  370.47  363.65  364.12   25332853
# 2  2020-07-06 04:00:00  370.00  375.78  369.87  373.81   26084791
# 3  2020-07-07 04:00:00  375.41  378.62  372.23  372.64   24610596
# 4  2020-07-08 04:00:00  376.72  381.50  376.36  381.44   26025692
# ..                 ...     ...     ...     ...     ...        ...
# 60 2020-09-25 04:00:00  108.43  112.44  107.67  112.28  137542199
# 61 2020-09-28 04:00:00  114.98  115.32  112.78  115.00  119572328
# 62 2020-09-29 04:00:00  114.55  115.31  113.57  114.11   89264463
# 63 2020-09-30 04:00:00  113.77  117.25  113.62  115.61  115978209
# 64 2020-10-01 04:00:00  117.64  117.72  115.83  116.80   97603139
#
# [65 rows x 6 columns]

# %% [markdown]
# ## Ultimo Trade de un ticker

# %%
def lastTade(symbol):    
    headers ={"APCA-API-KEY-ID" : api_key, "APCA-API-SECRET-KEY":secret_key}
    endpoint = "https://data.alpaca.markets/v1/last/stocks/"+symbol
    r = requests.get(url = endpoint, headers = headers)
    js = r.json()['last']
    
    js['timestamp'] = pd.to_datetime(js['timestamp'])
    return js
    
lastTade("GGAL")
# Out:
# {'price': 10.06,
#  'size': 100,
#  'exchange': 15,
#  'cond1': 0,
#  'cond2': 0,
#  'cond3': 0,
#  'cond4': 0,
#  'timestamp': Timestamp('2021-06-15 19:59:30.215231721')}

# %% [markdown]
# ## Ultimo dato del libro

# %%
import pandas as pd

def lastQuote(symbol):    
    headers ={"APCA-API-KEY-ID" : api_key, "APCA-API-SECRET-KEY":secret_key}
    endpoint = "https://data.alpaca.markets/v1/last_quote/stocks/"+symbol
    r = requests.get(url = endpoint, headers = headers)
    js = r.json()['last']
    js['timestamp'] = pd.to_datetime(js['timestamp'])
    return js
    
lastQuote("GGAL")
# Out:
# {'askprice': 0,
#  'asksize': 0,
#  'askexchange': 15,
#  'bidprice': 0,
#  'bidsize': 0,
#  'bidexchange': 15,
#  'timestamp': Timestamp('2021-06-15 20:00:00.000040296')}

# %% [markdown]
# # Ruteo de ordenes

# %% [markdown]
# ## Orden de Compra/Venta  (POST)

# %%
def order(symbol, qty, side, tipo, time_in_force, limit_price, notional=0 ):    
    headers ={"APCA-API-KEY-ID" : api_key, "APCA-API-SECRET-KEY":secret_key}
    
    if notional > 0:
        params = {'symbol':symbol, 
                  'notional':notional, 
                  'side':side, 
                  'type':tipo,
                  'time_in_force':time_in_force,
                  'limit_price':limit_price, 
                  'order_class':'simple'
                 } 
    else:
        params = {'symbol':symbol, 
                  'qty':qty, 
                  'side':side, 
                  'type':tipo,
                  'time_in_force':time_in_force,
                  'limit_price':limit_price, 
                  'order_class':'simple'
                 }
    
    if tipo == 'market':
        del params['limit_price']
        
    r = requests.post(url = "https://paper-api.alpaca.markets/v2/orders", 
                      headers = headers, json = params)

    js = r.json()
    return js

# %%
lastQuote("SPY")
# Out:
# {'askprice': 424.62,
#  'asksize': 5,
#  'askexchange': 15,
#  'bidprice': 424.52,
#  'bidsize': 5,
#  'bidexchange': 15,
#  'timestamp': Timestamp('2021-06-15 20:58:00.000607735')}

# %%
lastTade("AAPL")
# Out:
# {'price': 129.795,
#  'size': 100,
#  'exchange': 15,
#  'cond1': 0,
#  'cond2': 0,
#  'cond3': 0,
#  'cond4': 0,
#  'timestamp': Timestamp('2021-06-15 19:59:59.406112099')}

# %% [markdown]
# ## Envio varias órdenes

# %%
import time
tickers = ['AAPL', 'SPY', 'QQQ','TSLA', 'AMZN']
monto = 10000

for ticker in tickers:
    px_last = lastTade(ticker)['price'] 
    bid = lastQuote(ticker)['bidprice'] 
    px = bid * 1.0001
    
    # Preguntar si la api no pincho, y si el mercado esta "normal"
    if (bid > 0) & (abs(bid/px_last-1) < 0.1):
        try:
            q = monto // px
            orden = order(symbol=ticker, qty=q, side='buy', tipo='limit', time_in_force='gtc', limit_price = px)
            print('ok',ticker, monto, px)
        except:
            print('error',ticker, monto, px)
    else:
        print(f'{ticker} no cumple condiciones, bid={bid}, ultimo_precio={px_last}')
    time.sleep(1)
# Out:
# AAPL no cumple condiciones, bid=0, ultimo_precio=129.795
# ok SPY 10000 424.56245199999995
# QQQ no cumple condiciones, bid=0, ultimo_precio=341.87
# TSLA no cumple condiciones, bid=0, ultimo_precio=598.905
# AMZN no cumple condiciones, bid=0, ultimo_precio=3381.73

# %%
# Ejerccio, leer el codigo de la funcion que devuelve todos los argumentos de la opcion ARG
# Arregla el tema año/fecha vencimiento

# %% [markdown]
# ### A mercado

# %%
tickers = ['AAPLLLL', 'SPY', 'QQQ','TSLA', 'AMZN']

ordenes = []
for ticker in tickers:
    try:
        orden = order(symbol=ticker, notional=1000, side='buy', 
                      tipo='market',time_in_force='gtc',limit_price=None, qty=None)        
        ordenes.append(orden)
        print(orden)
    except Exception as e:
        print(e)
        print(f'\n****Fallo en {ticker}****')
# Out:
# {'code': 40010001, 'message': 'could not find asset "AAPLLLL"'}
# {'code': 40010001, 'message': 'fractional orders must be DAY market orders'}
# {'code': 40010001, 'message': 'fractional orders must be DAY market orders'}
# {'code': 40010001, 'message': 'fractional orders must be DAY market orders'}
# {'code': 40010001, 'message': 'fractional orders must be DAY market orders'}

# %%
tickers = ['AAPL', 'SPY', 'QQQ','TSLA', 'AMZN', 'PAM','GGAL','CRESY','TGS','BBAR','LOMA']

monto = 10000
for ticker in tickers:
    try:
        px = lastTade(ticker)['price'] 
        q = monto // px
        orden = order(symbol=ticker, qty=q, side='buy', tipo='market', time_in_force='gtc', limit_price = px)
        print('ok',ticker, monto, px)
    except:
        print('error',ticker, monto, px)
# Out:
# ok AAPL 10000 129.795
# ok SPY 10000 424.6
# ok QQQ 10000 341.87
# ok TSLA 10000 598.905
# ok AMZN 10000 3381.73
# ok PAM 10000 17
# ok GGAL 10000 10.06
# ok CRESY 10000 6.93
# ok TGS 10000 5.26
# ok BBAR 10000 3.915
# ok LOMA 10000 7.14

# %% [markdown]
# ## Consulta de estado general

# %%
def orders(status="all", limit=500): 
    
    headers ={"APCA-API-KEY-ID" : api_key, "APCA-API-SECRET-KEY":secret_key}
    params = {'status':status, 
              'limit':limit}
    
    r = requests.get(url = "https://paper-api.alpaca.markets/v2/orders", 
                      headers = headers, params = params)

    js = r.json()
    df = pd.DataFrame(js)
    return df

listaOrdenes = orders(status='open')
listaOrdenes

# %% [markdown]
# ## Consulta puntual  (GET)

# %%
def getOrder(orderID):    
    headers ={"APCA-API-KEY-ID" : api_key, "APCA-API-SECRET-KEY":secret_key}
    base = "https://paper-api.alpaca.markets/v2/orders/"
    r = requests.get(url = base+orderID, headers = headers)
    
    js = r.json()
    return js

# %%
getOrder('9d701ae8-3738-490a-8b0e-9920609265af')
# Out:
# {'id': '9d701ae8-3738-490a-8b0e-9920609265af',
#  'client_order_id': 'd871e5fc-47c1-4487-ad3a-44fa3119e85f',
#  'created_at': '2021-05-26T22:36:11.103507Z',
#  'updated_at': '2021-05-26T22:36:11.103507Z',
#  'submitted_at': '2021-05-26T22:36:11.097865Z',
#  'filled_at': None,
#  'expired_at': None,
#  'canceled_at': None,
#  'failed_at': None,
#  'replaced_at': None,
#  'replaced_by': None,
#  'replaces': None,
#  'asset_id': 'b28f4066-5c6d-479b-a2af-85dc1a8f16fb',
#  'symbol': 'SPY',
#  'asset_class': 'us_equity',
#  'notional': None,
#  'qty': '23',
#  'filled_qty': '0',
#  'filled_avg_price': None,
#  'order_class': 'simple',
#  'order_type': 'limit',
#  'type': 'limit',
#  'side': 'buy',
#  'time_in_force': 'gtc',
#  'limit_price': '419.04',
#  'stop_price': None,
#  'status': 'accepted',
#  'extended_hours': False,
#  'legs': None,
#  'trail_percent': None,
#  'trail_price': None,
#  'hwm': None}

# %% [markdown]
# ## Modificación de orden  (PATCH)

# %%
def replaceOrder(order_id, qty=None, time_in_force=None, limit_price=None):    
    headers ={"APCA-API-KEY-ID" : api_key, "APCA-API-SECRET-KEY":secret_key}
    params = {'qty':qty, 
              'time_in_force':time_in_force,
              'limit_price':limit_price}
    
    endpoint = "https://paper-api.alpaca.markets/v2/orders/"+order_id
    r = requests.patch(url = endpoint, headers = headers, json = params)
    
    js = r.json()
    return js

# %% [markdown]
# ## Eliminar orden/ordenes (DELETE)

# %%
def cancelOrder(order_id):    
    headers ={"APCA-API-KEY-ID" : api_key, "APCA-API-SECRET-KEY":secret_key}
    endpoint = "https://paper-api.alpaca.markets/v2/orders/"+order_id
    r = requests.delete(url = endpoint,headers = headers)

# %%
def rajemo():    
    headers ={"APCA-API-KEY-ID" : api_key, "APCA-API-SECRET-KEY":secret_key}
    endpoint = "https://paper-api.alpaca.markets/v2/orders"
    r = requests.delete(url = endpoint,headers = headers)
    return r.json()

# %%
#rajemo()

# %% [markdown]
# ## Ver Posiciones Abiertas de la cuenta

# %%
def positions():    
    headers ={"APCA-API-KEY-ID" : api_key, "APCA-API-SECRET-KEY":secret_key}
    endpoint = "https://paper-api.alpaca.markets/v2/positions"
    r = requests.get(url = endpoint, headers = headers)
    js = r.json()
    
    if len(js):
        df = pd.DataFrame(positions())
        df = df.loc[:,['symbol','qty','side','avg_entry_price','market_value',
                       'cost_basis','unrealized_pl','current_price',
                       'lastday_price']]
    else:
        df = pd.DataFrame()
    return df
    
portf = positions()
portf
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Listado de acitivos

# %%
def assets(only_shorteables=False):    
    headers ={"APCA-API-KEY-ID" : api_key, "APCA-API-SECRET-KEY":secret_key}
    r = requests.get(url = "https://paper-api.alpaca.markets/v2/assets", 
                      headers = headers)

    js = r.json()
    df = pd.DataFrame(js)
    df = df.loc[df.status=='active'].drop(['status','class','easy_to_borrow',
                                          'tradable','marginable'], axis=1)
    
    if only_shorteables:
        df= df.loc[df.shortable == True]
        
    return df

# %%
activos = assets(only_shorteables=True)
activos
# Out:
#                                          id exchange symbol  \
# 0      ca56f277-6345-49e3-889a-6a748a4f1c79     NYSE    ABC
# 2      fd7ecda8-13ff-43e3-81cd-50a95a5f3bc9     NYSE    ABG
# 3      6b84cb5b-cd55-4951-bc51-2adc2929571d     NYSE    ABM
# 4      0f148c0c-7f48-4453-ad89-379f25c3cfea   NASDAQ   ABUS
# 6      739b64f4-2873-48f9-99a8-fcc2977cd19a   NASDAQ   ACAD
# ...                                     ...      ...    ...
# 11816  1a7a56e3-a4d4-4244-b67b-edcb66100f1a   NASDAQ   USWS
# 11817  27882f72-d8d8-48d1-9a36-6e0531fafb7a   NASDAQ   PIRS
# 11819  fd77bf5e-eef3-48e0-a616-22b6a0ab9724     NYSE    EDU
# 11820  7aeb539e-b713-4a70-8a99-563ddc35f5bb   NASDAQ   NNDM
# 11821  c5079b22-6990-4c30-b1a3-3af925a819de   NASDAQ   PRVB
#
#                                                     name  shortable  \
# 0                                AmerisourceBergen Corp.       True
# 2                          Asbury Automotive Group, Inc.       True
# 3                                   ABM Industries, Inc.       True
# 4             Arbutus Biopharma Corporation Common Stock       True
# 6               ACADIA Pharmaceuticals Inc. Common Stock       True
# ...                                                  ...        ...
# 11816      U.S. Well Services, Inc. Class A Common Stock       True
# 11817          Pieris Pharmaceuticals, Inc. Common Stock       True
# 11819  New Oriental Education and Technology Group, Inc.       True
# 11820     Nano Dimension Ltd. American Depositary Shares       True
# 11821                  Provention Bio, Inc. Common Stock       True
#
#        fractionable
# 0              True
# 2             False
# 3             False
# 4             False
# 6              True
# ...             ...
# 11816         False
# 11817         False
# 11819          True
# 11820          True
# 11821          True
#
# [5776 rows x 6 columns]

# %% [markdown]
# ## WatchLists

# %% [markdown]
# ## CRUD

# %% [markdown]
# * create
# * read
# * update
# * delete

# %% [markdown]
# ### Ver listas creadas (R)

# %%
def watchlist():    
    headers ={"APCA-API-KEY-ID" : api_key, "APCA-API-SECRET-KEY":secret_key}
    r = requests.get(url = "https://paper-api.alpaca.markets/v2/watchlists", 
                      headers = headers)

    js = r.json()
    df = pd.DataFrame(js)
    try:
        df.drop('account_id',axis=1, inplace=True)
    except:
        pass
    
    return df

# %%
watchlist()
# Out:
#                                      id                   created_at  \
# 0  3dbc0193-a0e9-4a98-8866-179eedd497db  2021-05-26T21:16:49.755463Z
#
#                     updated_at               name
# 0  2021-05-26T21:16:49.755463Z  Primary Watchlist

# %% [markdown]
# ### Obtener watchList xID

# %%
def getWatchlist(wID):    
    headers ={"APCA-API-KEY-ID" : api_key, "APCA-API-SECRET-KEY":secret_key}
    base = 'https://paper-api.alpaca.markets/v2/watchlists/'
    r = requests.get(url = base + wID, headers = headers)

    js = r.json()
    df = pd.DataFrame(js['assets'])
    try:
        df.set_index('symbol', inplace=True)
        df = df.loc[df.status=='active'].drop(['status','class','easy_to_borrow',
                                              'tradable','marginable'], axis=1)
    except:
        pass
    return df

# %%
wl = watchlist()
wl
# Out:
#                                      id                   created_at  \
# 0  3dbc0193-a0e9-4a98-8866-179eedd497db  2021-05-26T21:16:49.755463Z
#
#                     updated_at               name
# 0  2021-05-26T21:16:49.755463Z  Primary Watchlist

# %%
getWatchlist("3dbc0193-a0e9-4a98-8866-179eedd497db")
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Crear listas  (C)

# %%
def createWatchlist(name, symbols):    
    headers ={"APCA-API-KEY-ID" : api_key, "APCA-API-SECRET-KEY":secret_key}
    params = {'name':name, 'symbols':symbols}
    r = requests.post(url = "https://paper-api.alpaca.markets/v2/watchlists", 
                      headers = headers, json=params)
    
    js = r.json()
    try:
        df = pd.DataFrame(js['assets'])
        df.set_index('symbol', inplace=True)
        df = df.loc[df.status=='active'].drop(['status','class','easy_to_borrow',
                                              'tradable','marginable'], axis=1)
        
        id = js['id']
    except:
        id = None
        df = pd.DataFrame()
        print(js)
    
    return id, df

# %%
createWatchlist('Lista2',['AAPL','FB'])
# Out:
# ('e9746729-be2c-48ca-9d1f-12f14ae7609a',
#                                            id exchange  \
#  symbol
#  AAPL    b0b6dd9d-8b9b-48a9-ba46-b9d54906e415   NASDAQ
#  FB      fc6a5dcd-4a70-4b8d-b64f-d83a6dae9ba4   NASDAQ
#
#                                         name  shortable  fractionable
#  symbol
#  AAPL                Apple Inc. Common Stock       True          True
#  FB      Facebook, Inc. Class A Common Stock       True          True  )

# %%
createWatchlist('Lista2',['GGAL','AMZN'])
# Out:
# {'code': 40010001, 'message': 'watchlist name must be unique'}
# (None,
#  Empty DataFrame
#  Columns: []
#  Index: [])

# %%
createWatchlist('Lista3',['AAPL','FBBBB'])
# Out:
# {'code': 40010001, 'message': 'asset not found: FBBBB'}
# (None,
#  Empty DataFrame
#  Columns: []
#  Index: [])

# %%
wl = watchlist()

lista2_id = wl.loc[wl.name=="Lista2",'id'].values[0]
getWatchlist(lista2_id)
# Out:
#                                           id exchange  \
# symbol
# AAPL    b0b6dd9d-8b9b-48a9-ba46-b9d54906e415   NASDAQ
# FB      fc6a5dcd-4a70-4b8d-b64f-d83a6dae9ba4   NASDAQ
#
#                                        name  shortable  fractionable
# symbol
# AAPL                Apple Inc. Common Stock       True          True
# FB      Facebook, Inc. Class A Common Stock       True          True

# %%
wl
# Out:
#                                      id                   created_at  \
# 0  e9746729-be2c-48ca-9d1f-12f14ae7609a  2021-05-26T23:24:57.646446Z
# 1  3dbc0193-a0e9-4a98-8866-179eedd497db  2021-05-26T21:16:49.755463Z
#
#                     updated_at               name
# 0  2021-05-26T23:24:57.646446Z             Lista2
# 1  2021-05-26T21:16:49.755463Z  Primary Watchlist

# %% [markdown]
# ### Borrar watchList xID

# %%
def deleteWatchlist(wID):    
    headers ={"APCA-API-KEY-ID" : api_key, "APCA-API-SECRET-KEY":secret_key}
    endpoint = "https://paper-api.alpaca.markets/v2/watchlists/"+wID
    r = requests.delete(url = endpoint, headers = headers)
    js = r.text
    return js

# %%
wl = watchlist()

lista2_id = wl.loc[wl.name=="Lista2",'id'][0]
deleteWatchlist(lista2_id)
# Out:
# ''

# %%
watchlist()
# Out:
#                                      id                   created_at  \
# 0  3dbc0193-a0e9-4a98-8866-179eedd497db  2021-05-26T21:16:49.755463Z
#
#                     updated_at               name
# 0  2021-05-26T21:16:49.755463Z  Primary Watchlist

# %% [markdown]
# ### Modificar watchList xID (PUT)

# %%
def updateWatchlist(wID, lista):    
    headers ={"APCA-API-KEY-ID" : api_key, "APCA-API-SECRET-KEY":secret_key}
    params = {'symbols': lista}
    endpoint = "https://paper-api.alpaca.markets/v2/watchlists/"+wID
    r = requests.put(url = endpoint, headers = headers, json=params)
    
    return r

# %%
modif = updateWatchlist(wID='3dbc0193-a0e9-4a98-8866-179eedd497db', lista=['GGAL', 'AAPL', 'GOOGL'])
modif
# Out:
# <Response [200]>

# %% [markdown]
# ### Agregar Ticker a una watchList existente (POST)

# %%
def addTicker(wID, symbol):    
    headers ={"APCA-API-KEY-ID" : api_key, "APCA-API-SECRET-KEY":secret_key}
    params = {'symbol': symbol}
    endpoint = "https://paper-api.alpaca.markets/v2/watchlists/"+wID
    r = requests.post(url = endpoint, headers = headers, json=params)
    js = r.json()
    df = pd.DataFrame(js['assets'])
    df.set_index('symbol', inplace=True)
    df = df.loc[df.status=='active'].drop(['status','class','easy_to_borrow',
                                          'tradable','marginable'], axis=1)
    
    return df

# %%
watchlist()
# Out:
#                                      id                   created_at  \
# 0  3dbc0193-a0e9-4a98-8866-179eedd497db  2021-05-26T21:16:49.755463Z
#
#                     updated_at               name
# 0  2021-05-26T23:32:50.891665Z  Primary Watchlist

# %%
wl = watchlist()

pw_id = wl.loc[wl.name=="Primary Watchlist",'id'].values[0]
addTicker(pw_id,'SPY')
# Out:
#                                           id exchange  \
# symbol
# GGAL    d811ca12-80f0-4cd0-a6b8-917655c82ded   NASDAQ
# AAPL    b0b6dd9d-8b9b-48a9-ba46-b9d54906e415   NASDAQ
# GOOGL   69b15845-7c63-4586-b274-1cfdfe9df3d8   NASDAQ
# SPY     b28f4066-5c6d-479b-a2af-85dc1a8f16fb     ARCA
#
#                                                      name  shortable  \
# symbol
# GGAL    Grupo Financiero Galicia S.A. American Deposit...       True
# AAPL                              Apple Inc. Common Stock       True
# GOOGL                  Alphabet Inc. Class A Common Stock       True
# SPY                                SPDR S&P 500 ETF Trust       True
#
#         fractionable
# symbol
# GGAL           False
# AAPL            True
# GOOGL           True
# SPY             True
